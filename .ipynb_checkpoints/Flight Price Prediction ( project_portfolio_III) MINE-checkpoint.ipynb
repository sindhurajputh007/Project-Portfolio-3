# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("Train.xlsx")

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
## Prepare proposal document and final presentation.

# %%
# Question:
## 5w and h ## 
# 1. Which airline is most preffered airline.
# 2. Mean/Median price for which airline is highest and lowest.
# 3. For each flight which is the most common source and destination airport.
# 4. How many flights are going from each source airports and destination airport.
# 5. Which airline is having most non-stop flight.
# 6. Which day of week we have maximum and minimum flights?
# 7. During what time day we have more flights?
# 8. What is the average price for flights on each day of week?
#      a. Different hours of day [morning/afternoon/evening/night] what is the average price?
# 9. How price and duration of flight is varring?
# 10. For which source and destiantion you have maximum and minimum duration?

# %% [markdown]
# # Sanity Check

# %%
# check for duplicate data
# Date of Jorney is object need to be converted into Datetime.
# Dep_Time is fine.
# Arrival Time is incorrectly placed so need to fixed.
# Duration is available in HH:MM format need to be either in minutes or hours. checked
# Total_Stops should be numerical but right it is object.
# Check if Additional_Info column provides any meaning information or not.

# %%
## Drop Duplicates
df.drop_duplicates(inplace=True)

# %%
def time_minute(duration):
    dur = duration.split()
    min = 0
    for x in dur:
        if x[-1] == 'h':
            min = min + int(x[:-1])*60

        if x[-1] == 'm':
            min = min + int(int(x[:-1])) 
    return min

def convert_duration_to_minutes(time):
    '''
    This function converts duration in h m to minutes:
    input : hh:mm ,hh, mm
    return:
        min
    '''
    if len(time.split(' ')) >1 :
        hh,mm = time.split(' ')
        hh,mm = int(hh[:-1]),int(mm[:-1])
        duration = hh*60+mm
    else:
        if 'h' in time:
            duration = int(time[:-1])*60
        else:
            duration= int(time[:-1])
            
    return duration

# %%
# df['DepartureDateTime'] = df['Date_of_Journey'] + " "+ df['Dep_Time']
# df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
# df['Duration_min'] = df['Duration'].apply(lambda x: convert_duration_to_minutes(x))
# df['Duration_timedelta'] = pd.to_timedelta(df['Duration_min'], unit='m')
# df["ArrivalDateTime"] = df['DepartureDateTime'] + df['Duration_timedelta']

def create_arrival_time(df):
    '''
    This Function preprocess date_of_journey and duration to create departure and arrival date time.
    '''
    df['DepartureDateTime'] = df['Date_of_Journey'] + " "+ df['Dep_Time']
    df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
    df['Duration_min'] = df['Duration'].apply(lambda x: convert_duration_to_minutes(x))
    df['Duration_timedelta'] = pd.to_timedelta(df['Duration_min'], unit='m')
    df["ArrivalDateTime"] = df['DepartureDateTime'] + df['Duration_timedelta']
    return df

create_arrival_time(df)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5556\2267467950.py:12: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_5556\2267467950.py:12: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price   DepartureDateTime  Duration_min  \
# 0             No info   3897 2019-03-24 22:20:00           170
# 1             No info   7662 2019-05-01 05:50:00           445
# 2             No info  13882 2019-06-09 09:25:00          1140
# 3             No info   6218 2019-05-12 18:05:00           325
# 4             No info  13302 2019-03-01 16:50:00           285
# ...               ...    ...                 ...           ...
# 10678         No info   4107 2019-04-09 19:55:00           150
# 10679         No info   4145 2019-04-27 20:45:00           155
# 10680         No info   7229 2019-04-27 08:20:00           180
# 10681         No info  12648 2019-03-01 11:30:00           160
# 10682         No info  11753 2019-05-09 10:55:00           500
#
#       Duration_timedelta     ArrivalDateTime
# 0        0 days 02:50:00 2019-03-25 01:10:00
# 1        0 days 07:25:00 2019-05-01 13:15:00
# 2        0 days 19:00:00 2019-06-10 04:25:00
# 3        0 days 05:25:00 2019-05-12 23:30:00
# 4        0 days 04:45:00 2019-03-01 21:35:00
# ...                  ...                 ...
# 10678    0 days 02:30:00 2019-04-09 22:25:00
# 10679    0 days 02:35:00 2019-04-27 23:20:00
# 10680    0 days 03:00:00 2019-04-27 11:20:00
# 10681    0 days 02:40:00 2019-03-01 14:10:00
# 10682    0 days 08:20:00 2019-05-09 19:15:00
#
# [10463 rows x 15 columns]

# %%
df.drop(columns=['Date_of_Journey','Dep_Time','Arrival_Time','Duration'],axis=1,inplace=True)

# %%
stops_dict = {
    'non-stop':0,
    '2 stops':2,
    '1 stop':1,
    '3 stops':3,
    '4 stops':4
}
df['Total_Stops'] = df['Total_Stops'].replace(stops_dict)

# %%
df['Additional_Info'].value_counts()/len(df)*100
# Out:
# Additional_Info
# No info                         78.208927
# In-flight meal not included     18.407722
# No check-in baggage included     3.039281
# 1 Long layover                   0.181592
# Change airports                  0.066902
# Business class                   0.038230
# No Info                          0.028672
# 1 Short layover                  0.009557
# Red-eye flight                   0.009557
# 2 Long layover                   0.009557
# Name: count, dtype: float64

# %%
# Additional Info columns doesnot have any meaningful information.
df.drop(columns=['Additional_Info'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Total_Stops  Price  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL          0.0   3897
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0   7662
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00
# 1 2019-05-01 05:50:00           445    0 days 07:25:00 2019-05-01 13:15:00

# %% [markdown]
# #### Actions on Sanity Check

# %%
def convert_duration_to_minutes(time):
    '''
    This function converts duration in h m to minutes:
    input : hh:mm ,hh, mm
    return:
        min
    '''
    if len(time.split(' ')) >1 :
        hh,mm = time.split(' ')
        hh,mm = int(hh[:-1]),int(mm[:-1])
        duration = hh*60+mm
    else:
        if 'h' in time:
            duration = int(time[:-1])*60
        else:
            duration= int(time[:-1])
            
    return duration


def create_preprocess_date_time(df):
    '''
    This Function preprocess date_of_journey and duration to create departure and arrival date time.
    '''
    df['DepartureDateTime'] = df['Date_of_Journey'] + " "+ df['Dep_Time']
    df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
    df['Duration_min'] = df['Duration'].apply(lambda x: convert_duration_to_minutes(x))
    df['Duration_timedelta'] = pd.to_timedelta(df['Duration_min'], unit='m')
    df["ArrivalDateTime"] = df['DepartureDateTime'] + df['Duration_timedelta']
    return df

stops_dict = {
    'non-stop':0,
    '2 stops':2,
    '1 stop':1,
    '3 stops':3,
    '4 stops':4
}

## Running the process of prediction is also referred as inference:
def sanity_check(df,train=True):
    '''
    This function performs sanity check on the airline data.
    inputs:
        df: dataframe that we need to perform sanity check
        train: This is used for process of training and inference.
            train is having default value of True and can be set as False if we are running inference.
            
        ## process for training    
        sanity_check(df)
        # process of prediction
        sanity_check(df,train=False)
    returns:
        df
    '''
    if train:
        df.drop_duplicates(inplace=True)
    
    create_preprocess_date_time(df)
    df['Total_Stops'] = df['Total_Stops'].replace(stops_dict)
    df.drop(columns=['Date_of_Journey','Dep_Time','Arrival_Time','Duration','Additional_Info'],axis=1,inplace=True)
    
    return df
    
## process for training    
sanity_check(df)
# process of prediction
sanity_check(df,train=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date_of_Journey'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[139], line 66
#      63     return df
#      65 ## process for training
# ---> 66 sanity_check(df)
#      67 # process of prediction
#      68 sanity_check(df,train=False)
#
# Cell In[139], line 59, in sanity_check(df, train)
#      56 if train:
#      57     df.drop_duplicates(inplace=True)
# ---> 59 create_preprocess_date_time(df)
#      60 df['Total_Stops'] = df['Total_Stops'].replace(stops_dict)
#      61 df.drop(columns=['Date_of_Journey','Dep_Time','Arrival_Time','Duration','Additional_Info'],axis=1,inplace=True)
#
# Cell In[139], line 25, in create_preprocess_date_time(df)
#      21 def create_preprocess_date_time(df):
#      22     '''
#      23     This Function preprocess date_of_journey and duration to create departure and arrival date time.
#      24     '''
# ---> 25     df['DepartureDateTime'] = df['Date_of_Journey'] + " "+ df['Dep_Time']
#      26     df['DepartureDateTime'] = pd.to_datetime(df['DepartureDateTime'],infer_datetime_format=True)
#      27     df['Duration_min'] = df['Duration'].apply(lambda x: convert_duration_to_minutes(x))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Date_of_Journey'

# %% [markdown]
# # Missing value Handling

# %%
# dropping Nan value as its a single observation.
df.dropna(inplace=True)

# %% [markdown]
# #### Actions on missing value

# %%
def handle_missing_value(df,train=True):
    """
    This function helps to handle missing value.
    Since for Airline data there is just one missing value we can choose to drop missing value.
    inputs:
         df: dataframe which requires imputation.
         
    returns:
        df
    
    """
    df.dropna(inplace=True)
    return df

handle_missing_value(df)
# Out:
#            Airline    Source Destination                  Route  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK          2.0
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL          1.0
# ...            ...       ...         ...                    ...          ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR          0.0
# 10679    Air India   Kolkata    Banglore              CCU → BLR          0.0
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL          0.0
# 10681      Vistara  Banglore   New Delhi              BLR → DEL          0.0
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK          2.0
#
#        Price   DepartureDateTime  Duration_min Duration_timedelta  \
# 0       3897 2019-03-24 22:20:00           170    0 days 02:50:00
# 1       7662 2019-05-01 05:50:00           445    0 days 07:25:00
# 2      13882 2019-06-09 09:25:00          1140    0 days 19:00:00
# 3       6218 2019-05-12 18:05:00           325    0 days 05:25:00
# 4      13302 2019-03-01 16:50:00           285    0 days 04:45:00
# ...      ...                 ...           ...                ...
# 10678   4107 2019-04-09 19:55:00           150    0 days 02:30:00
# 10679   4145 2019-04-27 20:45:00           155    0 days 02:35:00
# 10680   7229 2019-04-27 08:20:00           180    0 days 03:00:00
# 10681  12648 2019-03-01 11:30:00           160    0 days 02:40:00
# 10682  11753 2019-05-09 10:55:00           500    0 days 08:20:00
#
#           ArrivalDateTime
# 0     2019-03-25 01:10:00
# 1     2019-05-01 13:15:00
# 2     2019-06-10 04:25:00
# 3     2019-05-12 23:30:00
# 4     2019-03-01 21:35:00
# ...                   ...
# 10678 2019-04-09 22:25:00
# 10679 2019-04-27 23:20:00
# 10680 2019-04-27 11:20:00
# 10681 2019-03-01 14:10:00
# 10682 2019-05-09 19:15:00
#
# [10460 rows x 10 columns]

# %% [markdown]
# # Handling Categorical Values

# %%
df['Destination'] = df['Destination'].replace({'New Delhi':'Delhi'})

# %%
# No order in columns
categorical_cols = ['Airline', 'Source', 'Destination', 'Route']
for col in categorical_cols:
    print("Column :",col," Unique values :",df[col].unique()," and No. of uniques : ",df[col].nunique())
    print("-"*90)
# Out:
# Column : Airline  Unique values : ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']  and No. of uniques :  12
# ------------------------------------------------------------------------------------------
# Column : Source  Unique values : ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']  and No. of uniques :  5
# ------------------------------------------------------------------------------------------
# Column : Destination  Unique values : ['Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Hyderabad']  and No. of uniques :  5
# ------------------------------------------------------------------------------------------
# Column : Route  Unique values : ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK'
#  'CCU → NAG → BLR' 'BLR → NAG → DEL' 'CCU → BLR' 'BLR → BOM → DEL'
#  'DEL → BOM → COK' 'DEL → BLR → COK' 'MAA → CCU' 'CCU → BOM → BLR'
#  'DEL → AMD → BOM → COK' 'DEL → PNQ → COK' 'DEL → CCU → BOM → COK'
#  'BLR → COK → DEL' 'DEL → IDR → BOM → COK' 'DEL → LKO → COK'
#  'CCU → GAU → DEL → BLR' 'DEL → NAG → BOM → COK' 'CCU → MAA → BLR'
#  'DEL → HYD → COK' 'CCU → HYD → BLR' 'DEL → COK' 'CCU → DEL → BLR'
#  'BLR → BOM → AMD → DEL' 'BOM → DEL → HYD' 'DEL → MAA → COK' 'BOM → HYD'
#  'DEL → BHO → BOM → COK' 'DEL → JAI → BOM → COK' 'DEL → ATQ → BOM → COK'
#  'DEL → JDH → BOM → COK' 'CCU → BBI → BOM → BLR' 'BLR → MAA → DEL'
#  'DEL → GOI → BOM → COK' 'DEL → BDQ → BOM → COK' 'CCU → JAI → BOM → BLR'
#  'CCU → BBI → BLR' 'BLR → HYD → DEL' 'DEL → TRV → COK'
#  'CCU → IXR → DEL → BLR' 'DEL → IXU → BOM → COK' 'CCU → IXB → BLR'
#  'BLR → BOM → JDH → DEL' 'DEL → UDR → BOM → COK' 'DEL → HYD → MAA → COK'
#  'CCU → BOM → COK → BLR' 'BLR → CCU → DEL' 'CCU → BOM → GOI → BLR'
#  'DEL → RPR → NAG → BOM → COK' 'DEL → HYD → BOM → COK'
#  'CCU → DEL → AMD → BLR' 'CCU → PNQ → BLR' 'BLR → CCU → GAU → DEL'
#  'CCU → DEL → COK → BLR' 'BLR → PNQ → DEL' 'BOM → JDH → DEL → HYD'
#  'BLR → BOM → BHO → DEL' 'DEL → AMD → COK' 'BLR → LKO → DEL'
#  'CCU → GAU → BLR' 'BOM → GOI → HYD' 'CCU → BOM → AMD → BLR'
#  'CCU → BBI → IXR → DEL → BLR' 'DEL → DED → BOM → COK'
#  'DEL → MAA → BOM → COK' 'BLR → AMD → DEL' 'BLR → VGA → DEL'
#  'CCU → JAI → DEL → BLR' 'CCU → AMD → BLR' 'CCU → VNS → DEL → BLR'
#  'BLR → BOM → IDR → DEL' 'BLR → BBI → DEL' 'BLR → GOI → DEL'
#  'BOM → AMD → ISK → HYD' 'BOM → DED → DEL → HYD' 'DEL → IXC → BOM → COK'
#  'CCU → PAT → BLR' 'BLR → CCU → BBI → DEL' 'CCU → BBI → HYD → BLR'
#  'BLR → BOM → NAG → DEL' 'BLR → CCU → BBI → HYD → DEL' 'BLR → GAU → DEL'
#  'BOM → BHO → DEL → HYD' 'BOM → JLR → HYD' 'BLR → HYD → VGA → DEL'
#  'CCU → KNU → BLR' 'CCU → BOM → PNQ → BLR' 'DEL → BBI → COK'
#  'BLR → VGA → HYD → DEL' 'BOM → JDH → JAI → DEL → HYD'
#  'DEL → GWL → IDR → BOM → COK' 'CCU → RPR → HYD → BLR' 'CCU → VTZ → BLR'
#  'CCU → DEL → VGA → BLR' 'BLR → BOM → IDR → GWL → DEL'
#  'CCU → DEL → COK → TRV → BLR' 'BOM → COK → MAA → HYD' 'BOM → NDC → HYD'
#  'BLR → BDQ → DEL' 'CCU → BOM → TRV → BLR' 'CCU → BOM → HBX → BLR'
#  'BOM → BDQ → DEL → HYD' 'BOM → CCU → HYD' 'BLR → TRV → COK → DEL'
#  'BLR → IDR → DEL' 'CCU → IXZ → MAA → BLR' 'CCU → GAU → IMF → DEL → BLR'
#  'BOM → GOI → PNQ → HYD' 'BOM → BLR → CCU → BBI → HYD' 'BOM → MAA → HYD'
#  'BLR → BOM → UDR → DEL' 'BOM → UDR → DEL → HYD' 'BLR → VGA → VTZ → DEL'
#  'BLR → HBX → BOM → BHO → DEL' 'CCU → IXA → BLR' 'BOM → RPR → VTZ → HYD'
#  'BLR → HBX → BOM → AMD → DEL' 'BOM → IDR → DEL → HYD' 'BOM → BLR → HYD'
#  'BLR → STV → DEL' 'CCU → IXB → DEL → BLR' 'BOM → JAI → DEL → HYD'
#  'BOM → VNS → DEL → HYD' 'BLR → HBX → BOM → NAG → DEL'
#  'BLR → BOM → IXC → DEL' 'BLR → CCU → BBI → HYD → VGA → DEL'
#  'BOM → BBI → HYD']  and No. of uniques :  128
# ------------------------------------------------------------------------------------------

# %%
col = 'Airline'

# %%
df.groupby(col).size()
# Out:
# Airline
# Air Asia                              318
# Air India                            1694
# GoAir                                 194
# IndiGo                               2043
# Jet Airways                          3700
# Jet Airways Business                    6
# Multiple carriers                    1196
# Multiple carriers Premium economy      13
# SpiceJet                              815
# Trujet                                  1
# Vistara                               477
# Vistara Premium economy                 3
# dtype: int64

# %%
freq_value = df.groupby(col).size()/len(df)

# %%
freq_value
# Out:
# Airline
# Air Asia                             0.030402
# Air India                            0.161950
# GoAir                                0.018547
# IndiGo                               0.195315
# Jet Airways                          0.353728
# Jet Airways Business                 0.000574
# Multiple carriers                    0.114340
# Multiple carriers Premium economy    0.001243
# SpiceJet                             0.077916
# Trujet                               0.000096
# Vistara                              0.045602
# Vistara Premium economy              0.000287
# dtype: float64

# %%
freq_dict = freq_value.to_dict()

# %%
freq_dict
# Out:
# {'Air Asia': 0.03040152963671128,
#  'Air India': 0.16195028680688336,
#  'GoAir': 0.018546845124282983,
#  'IndiGo': 0.19531548757170172,
#  'Jet Airways': 0.35372848948374763,
#  'Jet Airways Business': 0.0005736137667304016,
#  'Multiple carriers': 0.11434034416826004,
#  'Multiple carriers Premium economy': 0.00124282982791587,
#  'SpiceJet': 0.07791586998087954,
#  'Trujet': 9.560229445506692e-05,
#  'Vistara': 0.04560229445506692,
#  'Vistara Premium economy': 0.0002868068833652008}

# %%
df["Freq_encoded_"+col] = df[col].replace(freq_dict)

# %%
df.head(1)
# Out:
#   Airline    Source Destination      Route  Total_Stops  Price  \
# 0  IndiGo  Banglore       Delhi  BLR → DEL          0.0   3897
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime  \
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00
#
#    Freq_encoded_Airline
# 0              0.195315

# %%
def frequency_encoder(df,col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          frequency encoded dictionary for columns
    """
    freq_value = df.groupby(col).size()/len(df)
    freq_dict = freq_value.to_dict()
    df["Freq_encoded_"+col] = df[col].replace(freq_dict)
    return freq_dict

# %%
col = 'Airline'
target_col = 'Price'

# %%
mean_value = df.groupby(col)[target_col].mean()

# %%
mean_value
# Out:
# Airline
# Air Asia                              5593.745283
# Air India                             9556.608028
# GoAir                                 5861.056701
# IndiGo                                5668.469897
# Jet Airways                          11599.021081
# Jet Airways Business                 58358.666667
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# SpiceJet                              4335.841718
# Trujet                                4140.000000
# Vistara                               7801.761006
# Vistara Premium economy               8962.333333
# Name: Price, dtype: float64

# %%
mean_dict = mean_value.to_dict()

# %%
mean_dict
# Out:
# {'Air Asia': 5593.745283018868,
#  'Air India': 9556.6080283353,
#  'GoAir': 5861.056701030928,
#  'IndiGo': 5668.469897209985,
#  'Jet Airways': 11599.02108108108,
#  'Jet Airways Business': 58358.666666666664,
#  'Multiple carriers': 10902.678093645485,
#  'Multiple carriers Premium economy': 11418.846153846154,
#  'SpiceJet': 4335.841717791411,
#  'Trujet': 4140.0,
#  'Vistara': 7801.761006289308,
#  'Vistara Premium economy': 8962.333333333334}

# %%
df["Mean_encoded_"+col] = df[col].replace(mean_dict)

# %%
df.head(1)
# Out:
#   Airline    Source Destination      Route  Total_Stops  Price  \
# 0  IndiGo  Banglore       Delhi  BLR → DEL          0.0   3897
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime  \
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00
#
#    Freq_encoded_Airline  Mean_encoded_Airline
# 0              0.195315           5668.469897

# %%
def mean_encoder(df,col,target_col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          Mean encoded dict for column
    """
    mean_value = df.groupby(col)[target_col].mean()
    mean_dict = mean_value.to_dict()
    df["Mean_encoded_"+col] = df[col].replace(mean_dict)
    return mean_dict

# %%
## Label encoder for function and later usages:

## Applying Label Encoder to Categorical columns as Hit and Trail.
from sklearn.preprocessing import LabelEncoder

def label_encoder(df,col):
    """
    This function encodes a categorical column based on the basis of their order label.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          label encoded dict for column
    """
    le = LabelEncoder()
    le.fit(df[col])
    label_dict = dict(zip((le.classes_),le.transform(le.classes_)))
    df["Label_encoded_"+col] = df[col].replace(label_dict)
    return label_dict

# %%
## Create a function to handle categorical value
def handle_categorical_values(df,target):
    '''
      This function handles categorical value and create a dataframe.
      Input:
        df : Dataframe which require categorical value treatment
      returns :
         Dataframe with all categorical value handled.
    '''
    encoded_dict = {}
    # Getting all object columns
    object_columns = df.select_dtypes(object).columns

    ## generate frequency encoded categorical values
    frequency_encoded_dict ={} 
    for col in object_columns:
        freq_dict = frequency_encoder(df,col)
        frequency_encoded_dict[col] = freq_dict

    ## generate target mean encoded categorical values
    mean_encoded_dict ={} 
    for col in object_columns:
        mean_dict = mean_encoder(df,col,target)
        mean_encoded_dict[col] = mean_dict

    
    ## generate label encoded categorical values
    label_encoded_dict ={} 
    for col in object_columns:
        label_dict = label_encoder(df,col)
        label_encoded_dict[col] = label_dict
    
    encoded_dict["Frequency"] = frequency_encoded_dict
    encoded_dict["Mean"] = mean_encoded_dict
    encoded_dict["Label"] = label_encoded_dict

    return df, encoded_dict

# %%
df.select_dtypes(object).columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route'], dtype='object')

# %%
target = 'Price'
df, encoded_dict = handle_categorical_values(df,target)

# %%
encoded_dict
# Out:
# {'Frequency': {'Airline': {'Air Asia': 0.03040152963671128,
#    'Air India': 0.16195028680688336,
#    'GoAir': 0.018546845124282983,
#    'IndiGo': 0.19531548757170172,
#    'Jet Airways': 0.35372848948374763,
#    'Jet Airways Business': 0.0005736137667304016,
#    'Multiple carriers': 0.11434034416826004,
#    'Multiple carriers Premium economy': 0.00124282982791587,
#    'SpiceJet': 0.07791586998087954,
#    'Trujet': 9.560229445506692e-05,
#    'Vistara': 0.04560229445506692,
#    'Vistara Premium economy': 0.0002868068833652008},
#   'Source': {'Banglore': 0.20812619502868068,
#    'Chennai': 0.0364244741873805,
#    'Delhi': 0.41539196940726575,
#    'Kolkata': 0.2734225621414914,
#    'Mumbai': 0.06663479923518165},
#   'Destination': {'Banglore': 0.2734225621414914,
#    'Cochin': 0.41539196940726575,
#    'Delhi': 0.20812619502868068,
#    'Hyderabad': 0.06663479923518165,
#    'Kolkata': 0.0364244741873805},
#   'Route': {'BLR → AMD → DEL': 0.0017208413001912047,
#    'BLR → BBI → DEL': 0.0004780114722753346,
#    'BLR → BDQ → DEL': 0.0007648183556405354,
#    'BLR → BOM → AMD → DEL': 0.0003824091778202677,
#    'BLR → BOM → BHO → DEL': 0.001051625239005736,
#    'BLR → BOM → DEL': 0.038432122370936905,
#    'BLR → BOM → IDR → DEL': 0.0004780114722753346,
#    'BLR → BOM → IDR → GWL → DEL': 0.00019120458891013384,
#    'BLR → BOM → IXC → DEL': 9.560229445506692e-05,
#    'BLR → BOM → JDH → DEL': 0.0005736137667304016,
#    'BLR → BOM → NAG → DEL': 0.0008604206500956023,
#    'BLR → BOM → UDR → DEL': 0.0002868068833652008,
#    'BLR → CCU → BBI → DEL': 0.0004780114722753346,
#    'BLR → CCU → BBI → HYD → DEL': 0.00019120458891013384,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 9.560229445506692e-05,
#    'BLR → CCU → DEL': 0.001051625239005736,
#    'BLR → CCU → GAU → DEL': 0.001051625239005736,
#    'BLR → COK → DEL': 0.0014340344168260039,
#    'BLR → DEL': 0.14665391969407265,
#    'BLR → GAU → DEL': 0.0002868068833652008,
#    'BLR → GOI → DEL': 0.0006692160611854684,
#    'BLR → HBX → BOM → AMD → DEL': 9.560229445506692e-05,
#    'BLR → HBX → BOM → BHO → DEL': 9.560229445506692e-05,
#    'BLR → HBX → BOM → NAG → DEL': 9.560229445506692e-05,
#    'BLR → HYD → DEL': 0.003537284894837476,
#    'BLR → HYD → VGA → DEL': 0.0009560229445506692,
#    'BLR → IDR → DEL': 0.0004780114722753346,
#    'BLR → LKO → DEL': 0.0002868068833652008,
#    'BLR → MAA → DEL': 0.002772466539196941,
#    'BLR → NAG → DEL': 0.0002868068833652008,
#    'BLR → PNQ → DEL': 0.0004780114722753346,
#    'BLR → STV → DEL': 0.00019120458891013384,
#    'BLR → TRV → COK → DEL': 0.00019120458891013384,
#    'BLR → VGA → DEL': 0.0008604206500956023,
#    'BLR → VGA → HYD → DEL': 0.0003824091778202677,
#    'BLR → VGA → VTZ → DEL': 0.00019120458891013384,
#    'BOM → AMD → ISK → HYD': 0.0003824091778202677,
#    'BOM → BBI → HYD': 9.560229445506692e-05,
#    'BOM → BDQ → DEL → HYD': 0.00019120458891013384,
#    'BOM → BHO → DEL → HYD': 0.0006692160611854684,
#    'BOM → BLR → CCU → BBI → HYD': 9.560229445506692e-05,
#    'BOM → BLR → HYD': 0.0002868068833652008,
#    'BOM → CCU → HYD': 9.560229445506692e-05,
#    'BOM → COK → MAA → HYD': 9.560229445506692e-05,
#    'BOM → DED → DEL → HYD': 9.560229445506692e-05,
#    'BOM → DEL → HYD': 0.0031548757170172083,
#    'BOM → GOI → HYD': 9.560229445506692e-05,
#    'BOM → GOI → PNQ → HYD': 0.0005736137667304016,
#    'BOM → HYD': 0.05936902485659656,
#    'BOM → IDR → DEL → HYD': 0.00019120458891013384,
#    'BOM → JAI → DEL → HYD': 9.560229445506692e-05,
#    'BOM → JDH → DEL → HYD': 0.0002868068833652008,
#    'BOM → JDH → JAI → DEL → HYD': 9.560229445506692e-05,
#    'BOM → JLR → HYD': 9.560229445506692e-05,
#    'BOM → MAA → HYD': 0.0002868068833652008,
#    'BOM → NDC → HYD': 9.560229445506692e-05,
#    'BOM → RPR → VTZ → HYD': 9.560229445506692e-05,
#    'BOM → UDR → DEL → HYD': 9.560229445506692e-05,
#    'BOM → VNS → DEL → HYD': 9.560229445506692e-05,
#    'CCU → AMD → BLR': 0.001051625239005736,
#    'CCU → BBI → BLR': 0.004780114722753346,
#    'CCU → BBI → BOM → BLR': 0.00401529636711281,
#    'CCU → BBI → HYD → BLR': 0.0008604206500956023,
#    'CCU → BBI → IXR → DEL → BLR': 0.00019120458891013384,
#    'CCU → BLR': 0.06921606118546846,
#    'CCU → BOM → AMD → BLR': 0.0008604206500956023,
#    'CCU → BOM → BLR': 0.09359464627151051,
#    'CCU → BOM → COK → BLR': 0.0028680688336520078,
#    'CCU → BOM → GOI → BLR': 0.00124282982791587,
#    'CCU → BOM → HBX → BLR': 0.0005736137667304016,
#    'CCU → BOM → PNQ → BLR': 0.0003824091778202677,
#    'CCU → BOM → TRV → BLR': 0.00019120458891013384,
#    'CCU → DEL → AMD → BLR': 0.002007648183556405,
#    'CCU → DEL → BLR': 0.05401529636711281,
#    'CCU → DEL → COK → BLR': 0.002772466539196941,
#    'CCU → DEL → COK → TRV → BLR': 0.0003824091778202677,
#    'CCU → DEL → VGA → BLR': 0.0003824091778202677,
#    'CCU → GAU → BLR': 0.003919694072657744,
#    'CCU → GAU → DEL → BLR': 0.003632887189292543,
#    'CCU → GAU → IMF → DEL → BLR': 0.0004780114722753346,
#    'CCU → HYD → BLR': 0.005066921606118547,
#    'CCU → IXA → BLR': 9.560229445506692e-05,
#    'CCU → IXB → BLR': 0.0019120458891013384,
#    'CCU → IXB → DEL → BLR': 9.560229445506692e-05,
#    'CCU → IXR → BBI → BLR': 0.0005736137667304016,
#    'CCU → IXR → DEL → BLR': 0.004397705544933079,
#    'CCU → IXZ → MAA → BLR': 9.560229445506692e-05,
#    'CCU → JAI → BOM → BLR': 0.00124282982791587,
#    'CCU → JAI → DEL → BLR': 0.0005736137667304016,
#    'CCU → KNU → BLR': 0.0009560229445506692,
#    'CCU → MAA → BLR': 0.00621414913957935,
#    'CCU → NAG → BLR': 0.0008604206500956023,
#    'CCU → PAT → BLR': 0.0009560229445506692,
#    'CCU → PNQ → BLR': 0.0018164435946462715,
#    'CCU → RPR → HYD → BLR': 9.560229445506692e-05,
#    'CCU → VNS → DEL → BLR': 0.0009560229445506692,
#    'CCU → VTZ → BLR': 9.560229445506692e-05,
#    'DEL → AMD → BOM → COK': 0.013766730401529637,
#    'DEL → AMD → COK': 0.002390057361376673,
#    'DEL → ATQ → BOM → COK': 0.0038240917782026767,
#    'DEL → BBI → COK': 0.0004780114722753346,
#    'DEL → BDQ → BOM → COK': 0.0025812619502868068,
#    'DEL → BHO → BOM → COK': 0.004588910133843212,
#    'DEL → BLR → COK': 0.022179732313575527,
#    'DEL → BOM → COK': 0.227151051625239,
#    'DEL → CCU → BOM → COK': 0.004206500956022944,
#    'DEL → COK': 0.020363288718929253,
#    'DEL → DED → BOM → COK': 0.00019120458891013384,
#    'DEL → GOI → BOM → COK': 0.004206500956022944,
#    'DEL → GWL → IDR → BOM → COK': 0.0007648183556405354,
#    'DEL → HYD → BOM → COK': 0.004302103250478011,
#    'DEL → HYD → COK': 0.031166347992351816,
#    'DEL → HYD → MAA → COK': 0.007934990439770554,
#    'DEL → IDR → BOM → COK': 0.008604206500956023,
#    'DEL → IXC → BOM → COK': 0.001051625239005736,
#    'DEL → IXU → BOM → COK': 0.001147227533460803,
#    'DEL → JAI → BOM → COK': 0.017495219885277247,
#    'DEL → JDH → BOM → COK': 0.003537284894837476,
#    'DEL → LKO → BOM → COK': 0.003919694072657744,
#    'DEL → LKO → COK': 0.0016252390057361376,
#    'DEL → MAA → BOM → COK': 0.001051625239005736,
#    'DEL → MAA → COK': 0.01395793499043977,
#    'DEL → NAG → BOM → COK': 0.004206500956022944,
#    'DEL → PNQ → COK': 0.00401529636711281,
#    'DEL → RPR → NAG → BOM → COK': 0.0014340344168260039,
#    'DEL → TRV → COK': 0.0015296367112810707,
#    'DEL → UDR → BOM → COK': 0.0017208413001912047,
#    'MAA → CCU': 0.0364244741873805}},
#  'Mean': {'Airline': {'Air Asia': 5593.745283018868,
#    'Air India': 9556.6080283353,
#    'GoAir': 5861.056701030928,
#    'IndiGo': 5668.469897209985,
#    'Jet Airways': 11599.02108108108,
#    'Jet Airways Business': 58358.666666666664,
#    'Multiple carriers': 10902.678093645485,
#    'Multiple carriers Premium economy': 11418.846153846154,
#    'SpiceJet': 4335.841717791411,
#    'Trujet': 4140.0,
#    'Vistara': 7801.761006289308,
#    'Vistara Premium economy': 8962.333333333334},
#   'Source': {'Banglore': 8024.689940284796,
#    'Chennai': 4789.892388451443,
#    'Delhi': 10461.600690448791,
#    'Kolkata': 9143.083566433566,
#    'Mumbai': 5059.708751793401},
#   'Destination': {'Banglore': 9143.083566433566,
#    'Cochin': 10461.600690448791,
#    'Delhi': 8024.689940284796,
#    'Hyderabad': 5059.708751793401,
#    'Kolkata': 4789.892388451443},
#   'Route': {'BLR → AMD → DEL': 11134.166666666666,
#    'BLR → BBI → DEL': 11486.0,
#    'BLR → BDQ → DEL': 11550.5,
#    'BLR → BOM → AMD → DEL': 14155.75,
#    'BLR → BOM → BHO → DEL': 17211.545454545456,
#    'BLR → BOM → DEL': 15723.174129353234,
#    'BLR → BOM → IDR → DEL': 15360.6,
#    'BLR → BOM → IDR → GWL → DEL': 13387.0,
#    'BLR → BOM → IXC → DEL': 13303.0,
#    'BLR → BOM → JDH → DEL': 14845.833333333334,
#    'BLR → BOM → NAG → DEL': 14685.333333333334,
#    'BLR → BOM → UDR → DEL': 11937.666666666666,
#    'BLR → CCU → BBI → DEL': 9155.0,
#    'BLR → CCU → BBI → HYD → DEL': 12713.5,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 17686.0,
#    'BLR → CCU → DEL': 12260.272727272728,
#    'BLR → CCU → GAU → DEL': 11810.0,
#    'BLR → COK → DEL': 9139.133333333333,
#    'BLR → DEL': 5551.593220338983,
#    'BLR → GAU → DEL': 12508.333333333334,
#    'BLR → GOI → DEL': 8759.857142857143,
#    'BLR → HBX → BOM → AMD → DEL': 10573.0,
#    'BLR → HBX → BOM → BHO → DEL': 14195.0,
#    'BLR → HBX → BOM → NAG → DEL': 12358.0,
#    'BLR → HYD → DEL': 6473.027027027027,
#    'BLR → HYD → VGA → DEL': 10770.7,
#    'BLR → IDR → DEL': 7610.4,
#    'BLR → LKO → DEL': 7334.333333333333,
#    'BLR → MAA → DEL': 12071.965517241379,
#    'BLR → NAG → DEL': 11313.0,
#    'BLR → PNQ → DEL': 11888.4,
#    'BLR → STV → DEL': 5746.0,
#    'BLR → TRV → COK → DEL': 11838.0,
#    'BLR → VGA → DEL': 9002.222222222223,
#    'BLR → VGA → HYD → DEL': 9598.75,
#    'BLR → VGA → VTZ → DEL': 15361.0,
#    'BOM → AMD → ISK → HYD': 11762.0,
#    'BOM → BBI → HYD': 14408.0,
#    'BOM → BDQ → DEL → HYD': 22792.5,
#    'BOM → BHO → DEL → HYD': 13161.57142857143,
#    'BOM → BLR → CCU → BBI → HYD': 14260.0,
#    'BOM → BLR → HYD': 9045.0,
#    'BOM → CCU → HYD': 16666.0,
#    'BOM → COK → MAA → HYD': 9678.0,
#    'BOM → DED → DEL → HYD': 24115.0,
#    'BOM → DEL → HYD': 13379.515151515152,
#    'BOM → GOI → HYD': 7681.0,
#    'BOM → GOI → PNQ → HYD': 17082.0,
#    'BOM → HYD': 3932.8099838969406,
#    'BOM → IDR → DEL → HYD': 17049.0,
#    'BOM → JAI → DEL → HYD': 17926.0,
#    'BOM → JDH → DEL → HYD': 23867.0,
#    'BOM → JDH → JAI → DEL → HYD': 18293.0,
#    'BOM → JLR → HYD': 13552.0,
#    'BOM → MAA → HYD': 8598.333333333334,
#    'BOM → NDC → HYD': 4140.0,
#    'BOM → RPR → VTZ → HYD': 9736.0,
#    'BOM → UDR → DEL → HYD': 22950.0,
#    'BOM → VNS → DEL → HYD': 23528.0,
#    'CCU → AMD → BLR': 8382.636363636364,
#    'CCU → BBI → BLR': 6060.6,
#    'CCU → BBI → BOM → BLR': 10457.404761904761,
#    'CCU → BBI → HYD → BLR': 5790.333333333333,
#    'CCU → BBI → IXR → DEL → BLR': 12606.0,
#    'CCU → BLR': 4556.055248618784,
#    'CCU → BOM → AMD → BLR': 14424.444444444445,
#    'CCU → BOM → BLR': 11487.788559754852,
#    'CCU → BOM → COK → BLR': 12864.833333333334,
#    'CCU → BOM → GOI → BLR': 11809.76923076923,
#    'CCU → BOM → HBX → BLR': 10037.166666666666,
#    'CCU → BOM → PNQ → BLR': 10118.0,
#    'CCU → BOM → TRV → BLR': 12403.0,
#    'CCU → DEL → AMD → BLR': 13719.095238095239,
#    'CCU → DEL → BLR': 10763.258407079646,
#    'CCU → DEL → COK → BLR': 13486.241379310344,
#    'CCU → DEL → COK → TRV → BLR': 12941.25,
#    'CCU → DEL → VGA → BLR': 12533.25,
#    'CCU → GAU → BLR': 7612.682926829269,
#    'CCU → GAU → DEL → BLR': 13892.052631578947,
#    'CCU → GAU → IMF → DEL → BLR': 13537.4,
#    'CCU → HYD → BLR': 4910.018867924528,
#    'CCU → IXA → BLR': 9413.0,
#    'CCU → IXB → BLR': 9275.25,
#    'CCU → IXB → DEL → BLR': 15292.0,
#    'CCU → IXR → BBI → BLR': 7369.166666666667,
#    'CCU → IXR → DEL → BLR': 10969.065217391304,
#    'CCU → IXZ → MAA → BLR': 11522.0,
#    'CCU → JAI → BOM → BLR': 10874.692307692309,
#    'CCU → JAI → DEL → BLR': 12053.0,
#    'CCU → KNU → BLR': 8623.4,
#    'CCU → MAA → BLR': 5240.876923076923,
#    'CCU → NAG → BLR': 6279.333333333333,
#    'CCU → PAT → BLR': 10821.3,
#    'CCU → PNQ → BLR': 6703.421052631579,
#    'CCU → RPR → HYD → BLR': 6103.0,
#    'CCU → VNS → DEL → BLR': 15164.5,
#    'CCU → VTZ → BLR': 6301.0,
#    'DEL → AMD → BOM → COK': 12630.173611111111,
#    'DEL → AMD → COK': 5606.2,
#    'DEL → ATQ → BOM → COK': 16699.675,
#    'DEL → BBI → COK': 11062.6,
#    'DEL → BDQ → BOM → COK': 12339.444444444445,
#    'DEL → BHO → BOM → COK': 14120.645833333334,
#    'DEL → BLR → COK': 7559.612068965517,
#    'DEL → BOM → COK': 10954.205808080807,
#    'DEL → CCU → BOM → COK': 13962.431818181818,
#    'DEL → COK': 6315.816901408451,
#    'DEL → DED → BOM → COK': 19539.5,
#    'DEL → GOI → BOM → COK': 11941.818181818182,
#    'DEL → GWL → IDR → BOM → COK': 17292.75,
#    'DEL → HYD → BOM → COK': 11724.577777777778,
#    'DEL → HYD → COK': 7299.331288343558,
#    'DEL → HYD → MAA → COK': 9133.469879518072,
#    'DEL → IDR → BOM → COK': 14038.122222222222,
#    'DEL → IXC → BOM → COK': 12514.545454545454,
#    'DEL → IXU → BOM → COK': 19381.333333333332,
#    'DEL → JAI → BOM → COK': 12210.196721311475,
#    'DEL → JDH → BOM → COK': 16163.135135135135,
#    'DEL → LKO → BOM → COK': 13277.19512195122,
#    'DEL → LKO → COK': 7166.176470588235,
#    'DEL → MAA → BOM → COK': 9161.636363636364,
#    'DEL → MAA → COK': 7312.431506849315,
#    'DEL → NAG → BOM → COK': 12171.227272727272,
#    'DEL → PNQ → COK': 6602.071428571428,
#    'DEL → RPR → NAG → BOM → COK': 11021.533333333333,
#    'DEL → TRV → COK': 7835.625,
#    'DEL → UDR → BOM → COK': 13859.277777777777,
#    'MAA → CCU': 4789.892388451443}},
#  'Label': {'Airline': {'Air Asia': 0,
#    'Air India': 1,
#    'GoAir': 2,
#    'IndiGo': 3,
#    'Jet Airways': 4,
#    'Jet Airways Business': 5,
#    'Multiple carriers': 6,
#    'Multiple carriers Premium economy': 7,
#    'SpiceJet': 8,
#    'Trujet': 9,
#    'Vistara': 10,
#    'Vistara Premium economy': 11},
#   'Source': {'Banglore': 0,
#    'Chennai': 1,
#    'Delhi': 2,
#    'Kolkata': 3,
#    'Mumbai': 4},
#   'Destination': {'Banglore': 0,
#    'Cochin': 1,
#    'Delhi': 2,
#    'Hyderabad': 3,
#    'Kolkata': 4},
#   'Route': {'BLR → AMD → DEL': 0,
#    'BLR → BBI → DEL': 1,
#    'BLR → BDQ → DEL': 2,
#    'BLR → BOM → AMD → DEL': 3,
#    'BLR → BOM → BHO → DEL': 4,
#    'BLR → BOM → DEL': 5,
#    'BLR → BOM → IDR → DEL': 6,
#    'BLR → BOM → IDR → GWL → DEL': 7,
#    'BLR → BOM → IXC → DEL': 8,
#    'BLR → BOM → JDH → DEL': 9,
#    'BLR → BOM → NAG → DEL': 10,
#    'BLR → BOM → UDR → DEL': 11,
#    'BLR → CCU → BBI → DEL': 12,
#    'BLR → CCU → BBI → HYD → DEL': 13,
#    'BLR → CCU → BBI → HYD → VGA → DEL': 14,
#    'BLR → CCU → DEL': 15,
#    'BLR → CCU → GAU → DEL': 16,
#    'BLR → COK → DEL': 17,
#    'BLR → DEL': 18,
#    'BLR → GAU → DEL': 19,
#    'BLR → GOI → DEL': 20,
#    'BLR → HBX → BOM → AMD → DEL': 21,
#    'BLR → HBX → BOM → BHO → DEL': 22,
#    'BLR → HBX → BOM → NAG → DEL': 23,
#    'BLR → HYD → DEL': 24,
#    'BLR → HYD → VGA → DEL': 25,
#    'BLR → IDR → DEL': 26,
#    'BLR → LKO → DEL': 27,
#    'BLR → MAA → DEL': 28,
#    'BLR → NAG → DEL': 29,
#    'BLR → PNQ → DEL': 30,
#    'BLR → STV → DEL': 31,
#    'BLR → TRV → COK → DEL': 32,
#    'BLR → VGA → DEL': 33,
#    'BLR → VGA → HYD → DEL': 34,
#    'BLR → VGA → VTZ → DEL': 35,
#    'BOM → AMD → ISK → HYD': 36,
#    'BOM → BBI → HYD': 37,
#    'BOM → BDQ → DEL → HYD': 38,
#    'BOM → BHO → DEL → HYD': 39,
#    'BOM → BLR → CCU → BBI → HYD': 40,
#    'BOM → BLR → HYD': 41,
#    'BOM → CCU → HYD': 42,
#    'BOM → COK → MAA → HYD': 43,
#    'BOM → DED → DEL → HYD': 44,
#    'BOM → DEL → HYD': 45,
#    'BOM → GOI → HYD': 46,
#    'BOM → GOI → PNQ → HYD': 47,
#    'BOM → HYD': 48,
#    'BOM → IDR → DEL → HYD': 49,
#    'BOM → JAI → DEL → HYD': 50,
#    'BOM → JDH → DEL → HYD': 51,
#    'BOM → JDH → JAI → DEL → HYD': 52,
#    'BOM → JLR → HYD': 53,
#    'BOM → MAA → HYD': 54,
#    'BOM → NDC → HYD': 55,
#    'BOM → RPR → VTZ → HYD': 56,
#    'BOM → UDR → DEL → HYD': 57,
#    'BOM → VNS → DEL → HYD': 58,
#    'CCU → AMD → BLR': 59,
#    'CCU → BBI → BLR': 60,
#    'CCU → BBI → BOM → BLR': 61,
#    'CCU → BBI → HYD → BLR': 62,
#    'CCU → BBI → IXR → DEL → BLR': 63,
#    'CCU → BLR': 64,
#    'CCU → BOM → AMD → BLR': 65,
#    'CCU → BOM → BLR': 66,
#    'CCU → BOM → COK → BLR': 67,
#    'CCU → BOM → GOI → BLR': 68,
#    'CCU → BOM → HBX → BLR': 69,
#    'CCU → BOM → PNQ → BLR': 70,
#    'CCU → BOM → TRV → BLR': 71,
#    'CCU → DEL → AMD → BLR': 72,
#    'CCU → DEL → BLR': 73,
#    'CCU → DEL → COK → BLR': 74,
#    'CCU → DEL → COK → TRV → BLR': 75,
#    'CCU → DEL → VGA → BLR': 76,
#    'CCU → GAU → BLR': 77,
#    'CCU → GAU → DEL → BLR': 78,
#    'CCU → GAU → IMF → DEL → BLR': 79,
#    'CCU → HYD → BLR': 80,
#    'CCU → IXA → BLR': 81,
#    'CCU → IXB → BLR': 82,
#    'CCU → IXB → DEL → BLR': 83,
#    'CCU → IXR → BBI → BLR': 84,
#    'CCU → IXR → DEL → BLR': 85,
#    'CCU → IXZ → MAA → BLR': 86,
#    'CCU → JAI → BOM → BLR': 87,
#    'CCU → JAI → DEL → BLR': 88,
#    'CCU → KNU → BLR': 89,
#    'CCU → MAA → BLR': 90,
#    'CCU → NAG → BLR': 91,
#    'CCU → PAT → BLR': 92,
#    'CCU → PNQ → BLR': 93,
#    'CCU → RPR → HYD → BLR': 94,
#    'CCU → VNS → DEL → BLR': 95,
#    'CCU → VTZ → BLR': 96,
#    'DEL → AMD → BOM → COK': 97,
#    'DEL → AMD → COK': 98,
#    'DEL → ATQ → BOM → COK': 99,
#    'DEL → BBI → COK': 100,
#    'DEL → BDQ → BOM → COK': 101,
#    'DEL → BHO → BOM → COK': 102,
#    'DEL → BLR → COK': 103,
#    'DEL → BOM → COK': 104,
#    'DEL → CCU → BOM → COK': 105,
#    'DEL → COK': 106,
#    'DEL → DED → BOM → COK': 107,
#    'DEL → GOI → BOM → COK': 108,
#    'DEL → GWL → IDR → BOM → COK': 109,
#    'DEL → HYD → BOM → COK': 110,
#    'DEL → HYD → COK': 111,
#    'DEL → HYD → MAA → COK': 112,
#    'DEL → IDR → BOM → COK': 113,
#    'DEL → IXC → BOM → COK': 114,
#    'DEL → IXU → BOM → COK': 115,
#    'DEL → JAI → BOM → COK': 116,
#    'DEL → JDH → BOM → COK': 117,
#    'DEL → LKO → BOM → COK': 118,
#    'DEL → LKO → COK': 119,
#    'DEL → MAA → BOM → COK': 120,
#    'DEL → MAA → COK': 121,
#    'DEL → NAG → BOM → COK': 122,
#    'DEL → PNQ → COK': 123,
#    'DEL → RPR → NAG → BOM → COK': 124,
#    'DEL → TRV → COK': 125,
#    'DEL → UDR → BOM → COK': 126,
#    'MAA → CCU': 127}}}

# %%
df.head(2)
# Out:
#      Airline    Source Destination                  Route  Total_Stops  Price  \
# 0     IndiGo  Banglore       Delhi              BLR → DEL          0.0   3897
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0   7662
#
#     DepartureDateTime  Duration_min Duration_timedelta     ArrivalDateTime  \
# 0 2019-03-24 22:20:00           170    0 days 02:50:00 2019-03-25 01:10:00
# 1 2019-05-01 05:50:00           445    0 days 07:25:00 2019-05-01 13:15:00
#
#    ...  Freq_encoded_Source  Freq_encoded_Destination  Freq_encoded_Route  \
# 0  ...             0.208126                  0.208126            0.146654
# 1  ...             0.273423                  0.273423            0.000574
#
#    Mean_encoded_Source  Mean_encoded_Destination  Mean_encoded_Route  \
# 0          8024.689940               8024.689940         5551.593220
# 1          9143.083566               9143.083566         7369.166667
#
#    Label_encoded_Airline  Label_encoded_Source  Label_encoded_Destination  \
# 0                      3                     0                          2
# 1                      1                     3                          0
#
#    Label_encoded_Route
# 0                   18
# 1                   84
#
# [2 rows x 22 columns]

# %%
categorical_cols = ['Airline', 'Source', 'Destination', 'Route']
df.drop(columns=categorical_cols,inplace=True)

# %% [markdown]
# #### Action on categorical Values

# %%
def frequency_encoder(df,col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          frequency encoded dictionary for columns
    """
    freq_value = df.groupby(col).size()/len(df)
    freq_dict = freq_value.to_dict()
    df["Freq_encoded_"+col] = df[col].replace(freq_dict)
    return freq_dict


def mean_encoder(df,col,target_col):
    """
    This function encodes a categorical column based on the frequency of their occurence.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          Mean encoded dict for column
    """
    mean_value = df.groupby(col)[target_col].mean()
    mean_dict = mean_value.to_dict()
    df["Mean_encoded_"+col] = df[col].replace(mean_dict)
    return mean_dict


from sklearn.preprocessing import LabelEncoder

def label_encoder(df,col):
    """
    This function encodes a categorical column based on the basis of their order label.
    input:
        df : Input DataFrame in which encoding has to be created 
        col : Column name which has to be encoded
    return: 
          label encoded dict for column
    """
    le = LabelEncoder()
    le.fit(df[col])
    label_dict = dict(zip((le.classes_),le.transform(le.classes_)))
    df["Label_encoded_"+col] = df[col].replace(label_dict)
    return label_dict


## Create a function to handle categorical value
def handle_categorical_values(df,target):
    '''
      This function handles categorical value and create a dataframe.
      Input:
        df : Dataframe which require categorical value treatment
      returns :
         Dataframe with all categorical value handled.
    '''
    encoded_dict = {}
    # Getting all object columns
    object_columns = df.select_dtypes(object).columns

    ## generate frequency encoded categorical values
    frequency_encoded_dict ={} 
    for col in object_columns:
        freq_dict = frequency_encoder(df,col)
        frequency_encoded_dict[col] = freq_dict

    ## generate target mean encoded categorical values
    mean_encoded_dict ={} 
    for col in object_columns:
        mean_dict = mean_encoder(df,col,target)
        mean_encoded_dict[col] = mean_dict

    
    ## generate label encoded categorical values
    label_encoded_dict ={} 
    for col in object_columns:
        label_dict = label_encoder(df,col)
        label_encoded_dict[col] = label_dict
    
    encoded_dict["Frequency"] = frequency_encoded_dict
    encoded_dict["Mean"] = mean_encoded_dict
    encoded_dict["Label"] = label_encoded_dict

    return df, encoded_dict


def airline_handle_categorical_data(df,target):
    df['Destination'] = df['Destination'].replace({'New Delhi':'Delhi'})
    df, encoded_dict = handle_categorical_values(df,target)
    categorical_cols = df.select_dtypes(object).columns
    df.drop(columns=categorical_cols,inplace=True)
    return df, encoded_dict

df, encoded_dict = airline_handle_categorical_data(df,'Price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Destination'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[168], line 95
#      92     df.drop(columns=categorical_cols,inplace=True)
#      93     return df, encoded_dict
# ---> 95 df, encoded_dict = airline_handle_categorical_data(df,'Price')
#
# Cell In[168], line 89, in airline_handle_categorical_data(df, target)
#      88 def airline_handle_categorical_data(df,target):
# ---> 89     df['Destination'] = df['Destination'].replace({'New Delhi':'Delhi'})
#      90     df, encoded_dict = handle_categorical_values(df,target)
#      91     categorical_cols = df.select_dtypes(object).columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Destination'

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#                            Total_Stops     Price  DepartureDateTime  \
# Total_Stops                   1.000000  0.601978           0.032399
# Price                         0.601978  1.000000          -0.149351
# DepartureDateTime             0.032399 -0.149351           1.000000
# Duration_min                  0.727930  0.501710          -0.003151
# Duration_timedelta            0.727930  0.501710          -0.003151
# ArrivalDateTime               0.039369 -0.144545           0.999954
# Freq_encoded_Airline          0.211540  0.371523           0.029162
# Mean_encoded_Airline          0.421230  0.638632           0.029197
# Freq_encoded_Source           0.571431  0.350924           0.160359
# Freq_encoded_Destination      0.571431  0.350924           0.160359
# Freq_encoded_Route           -0.205132  0.039251           0.105370
# Mean_encoded_Source           0.559075  0.359895           0.146251
# Mean_encoded_Destination      0.559075  0.359895           0.146251
# Mean_encoded_Route            0.806659  0.746261          -0.061108
# Label_encoded_Airline        -0.194563 -0.036592           0.031835
# Label_encoded_Source          0.193899  0.013597           0.178190
# Label_encoded_Destination    -0.422555 -0.260681          -0.146161
# Label_encoded_Route           0.441153  0.154228           0.249660
#
#                            Duration_min  Duration_timedelta  ArrivalDateTime  \
# Total_Stops                    0.727930            0.727930         0.039369
# Price                          0.501710            0.501710        -0.144545
# DepartureDateTime             -0.003151           -0.003151         0.999954
# Duration_min                   1.000000            1.000000         0.006424
# Duration_timedelta             1.000000            1.000000         0.006424
# ArrivalDateTime                0.006424            0.006424         1.000000
# Freq_encoded_Airline           0.289266            0.289266         0.031931
# Mean_encoded_Airline           0.433915            0.433915         0.033351
# Freq_encoded_Source            0.400030            0.400030         0.164187
# Freq_encoded_Destination       0.400030            0.400030         0.164187
# Freq_encoded_Route            -0.110685           -0.110685         0.104308
# Mean_encoded_Source            0.414838            0.414838         0.150221
# Mean_encoded_Destination       0.414838            0.414838         0.150221
# Mean_encoded_Route             0.671820            0.671820        -0.054674
# Label_encoded_Airline         -0.153627           -0.153627         0.030363
# Label_encoded_Source           0.162574            0.162574         0.179744
# Label_encoded_Destination     -0.383686           -0.383686        -0.149833
# Label_encoded_Route            0.273014            0.273014         0.252270
#
#                            Freq_encoded_Airline  Mean_encoded_Airline  \
# Total_Stops                            0.211540              0.421230
# Price                                  0.371523              0.638632
# DepartureDateTime                      0.029162              0.029197
# Duration_min                           0.289266              0.433915
# Duration_timedelta                     0.289266              0.433915
# ArrivalDateTime                        0.031931              0.033351
# Freq_encoded_Airline                   1.000000              0.581748
# Mean_encoded_Airline                   0.581748              1.000000
# Freq_encoded_Source                    0.037831              0.258409
# Freq_encoded_Destination               0.037831              0.258409
# Freq_encoded_Route                     0.019920              0.158756
# Mean_encoded_Source                    0.055943              0.257207
# Mean_encoded_Destination               0.055943              0.257207
# Mean_encoded_Route                     0.367383              0.572084
# Label_encoded_Airline                 -0.200418             -0.057298
# Label_encoded_Source                   0.055481              0.047572
# Label_encoded_Destination             -0.107185             -0.183375
# Label_encoded_Route                   -0.066232              0.071386
#
#                            Freq_encoded_Source  Freq_encoded_Destination  \
# Total_Stops                           0.571431                  0.571431
# Price                                 0.350924                  0.350924
# DepartureDateTime                     0.160359                  0.160359
# Duration_min                          0.400030                  0.400030
# Duration_timedelta                    0.400030                  0.400030
# ArrivalDateTime                       0.164187                  0.164187
# Freq_encoded_Airline                  0.037831                  0.037831
# Mean_encoded_Airline                  0.258409                  0.258409
# Freq_encoded_Source                   1.000000                  1.000000
# Freq_encoded_Destination              1.000000                  1.000000
# Freq_encoded_Route                    0.303417                  0.303417
# Mean_encoded_Source                   0.975075                  0.975075
# Mean_encoded_Destination              0.975075                  0.975075
# Mean_encoded_Route                    0.470243                  0.470243
# Label_encoded_Airline                -0.049686                 -0.049686
# Label_encoded_Source                  0.067241                  0.067241
# Label_encoded_Destination            -0.596100                 -0.596100
# Label_encoded_Route                   0.612391                  0.612391
#
#                            Freq_encoded_Route  Mean_encoded_Source  \
# Total_Stops                         -0.205132             0.559075
# Price                                0.039251             0.359895
# DepartureDateTime                    0.105370             0.146251
# Duration_min                        -0.110685             0.414838
# Duration_timedelta                  -0.110685             0.414838
# ArrivalDateTime                      0.104308             0.150221
# Freq_encoded_Airline                 0.019920             0.055943
# Mean_encoded_Airline                 0.158756             0.257207
# Freq_encoded_Source                  0.303417             0.975075
# Freq_encoded_Destination             0.303417             0.975075
# Freq_encoded_Route                   1.000000             0.272893
# Mean_encoded_Source                  0.272893             1.000000
# Mean_encoded_Destination             0.272893             1.000000
# Mean_encoded_Route                   0.052597             0.482264
# Label_encoded_Airline                0.194110            -0.059859
# Label_encoded_Source                -0.195724             0.037781
# Label_encoded_Destination           -0.001637            -0.724325
# Label_encoded_Route                  0.056397             0.496466
#
#                            Mean_encoded_Destination  Mean_encoded_Route  \
# Total_Stops                                0.559075            0.806659
# Price                                      0.359895            0.746261
# DepartureDateTime                          0.146251           -0.061108
# Duration_min                               0.414838            0.671820
# Duration_timedelta                         0.414838            0.671820
# ArrivalDateTime                            0.150221           -0.054674
# Freq_encoded_Airline                       0.055943            0.367383
# Mean_encoded_Airline                       0.257207            0.572084
# Freq_encoded_Source                        0.975075            0.470243
# Freq_encoded_Destination                   0.975075            0.470243
# Freq_encoded_Route                         0.272893            0.052597
# Mean_encoded_Source                        1.000000            0.482264
# Mean_encoded_Destination                   1.000000            0.482264
# Mean_encoded_Route                         0.482264            1.000000
# Label_encoded_Airline                     -0.059859           -0.058117
# Label_encoded_Source                       0.037781            0.018220
# Label_encoded_Destination                 -0.724325           -0.349316
# Label_encoded_Route                        0.496466            0.206667
#
#                            Label_encoded_Airline  Label_encoded_Source  \
# Total_Stops                            -0.194563              0.193899
# Price                                  -0.036592              0.013597
# DepartureDateTime                       0.031835              0.178190
# Duration_min                           -0.153627              0.162574
# Duration_timedelta                     -0.153627              0.162574
# ArrivalDateTime                         0.030363              0.179744
# Freq_encoded_Airline                   -0.200418              0.055481
# Mean_encoded_Airline                   -0.057298              0.047572
# Freq_encoded_Source                    -0.049686              0.067241
# Freq_encoded_Destination               -0.049686              0.067241
# Freq_encoded_Route                      0.194110             -0.195724
# Mean_encoded_Source                    -0.059859              0.037781
# Mean_encoded_Destination               -0.059859              0.037781
# Mean_encoded_Route                     -0.058117              0.018220
# Label_encoded_Airline                   1.000000             -0.012044
# Label_encoded_Source                   -0.012044              1.000000
# Label_encoded_Destination               0.068602             -0.432494
# Label_encoded_Route                     0.029782              0.403597
#
#                            Label_encoded_Destination  Label_encoded_Route
# Total_Stops                                -0.422555             0.441153
# Price                                      -0.260681             0.154228
# DepartureDateTime                          -0.146161             0.249660
# Duration_min                               -0.383686             0.273014
# Duration_timedelta                         -0.383686             0.273014
# ArrivalDateTime                            -0.149833             0.252270
# Freq_encoded_Airline                       -0.107185            -0.066232
# Mean_encoded_Airline                       -0.183375             0.071386
# Freq_encoded_Source                        -0.596100             0.612391
# Freq_encoded_Destination                   -0.596100             0.612391
# Freq_encoded_Route                         -0.001637             0.056397
# Mean_encoded_Source                        -0.724325             0.496466
# Mean_encoded_Destination                   -0.724325             0.496466
# Mean_encoded_Route                         -0.349316             0.206667
# Label_encoded_Airline                       0.068602             0.029782
# Label_encoded_Source                       -0.432494             0.403597
# Label_encoded_Destination                   1.000000            -0.229317
# Label_encoded_Route                        -0.229317             1.000000

# %%
from sklearn.model_selection import train_test_split

from sklearn import linear_model
from sklearn import metrics

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import SplineTransformer

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor


def regression(X_train, X_test, y_train, y_test):
    ## Baseline model
    reg = linear_model.LinearRegression()
    reg.fit(X_train,y_train)
    print(metrics.r2_score(y_train,reg.predict(X_train)), metrics.r2_score(y_test,reg.predict(X_test)))
    return reg

def knearestneighbour(X_train, X_test, y_train, y_test):
    knn_regressor = KNeighborsRegressor(n_neighbors=10)
    knn_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,knn_regressor.predict(X_train)),metrics.r2_score(y_test,knn_regressor.predict(X_test)))
    return knn_regressor

def decisiontree(X_train, X_test, y_train, y_test):
    tree = DecisionTreeRegressor(max_depth=10)
    tree.fit(X_train,y_train)
    print(metrics.r2_score(y_train,tree.predict(X_train)),metrics.r2_score(y_test,tree.predict(X_test)))
    return tree

def randomForest(X_train, X_test, y_train, y_test):
    random_regressor = RandomForestRegressor(n_estimators=500, min_samples_split=10,min_samples_leaf=2)
    random_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,random_regressor.predict(X_train)),metrics.r2_score(y_test,random_regressor.predict(X_test)))
    return random_regressor

from xgboost import XGBRegressor
def xgboost(X_train, X_test, y_train, y_test):
    xgboost_regressor = XGBRegressor()
    xgboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
    return xgboost_regressor

from catboost import  CatBoostRegressor
def catboost(X_train, X_test, y_train, y_test):
    catboost_regressor = CatBoostRegressor(verbose=False)
    catboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,catboost_regressor.predict(X_train)),metrics.r2_score(y_test,catboost_regressor.predict(X_test)))
    return catboost_regressor

from sklearn.ensemble import GradientBoostingRegressor
def gboost(X_train, X_test, y_train, y_test):
    gboost_regressor = GradientBoostingRegressor()
    gboost_regressor.fit(X_train, y_train)
    print(metrics.r2_score(y_train,gboost_regressor.predict(X_train)),metrics.r2_score(y_test,gboost_regressor.predict(X_test)))
    return gboost_regressor


def train(X,y,modelType):
    # Split your dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    model = modelType(X_train, X_test, y_train, y_test)
    return model

# %%
df.head(2)
# Out:
#    Total_Stops  Price   DepartureDateTime  Duration_min Duration_timedelta  \
# 0          0.0   3897 2019-03-24 22:20:00           170    0 days 02:50:00
# 1          2.0   7662 2019-05-01 05:50:00           445    0 days 07:25:00
#
#       ArrivalDateTime  Freq_encoded_Airline  Mean_encoded_Airline  \
# 0 2019-03-25 01:10:00              0.195315           5668.469897
# 1 2019-05-01 13:15:00              0.161950           9556.608028
#
#    Freq_encoded_Source  Freq_encoded_Destination  Freq_encoded_Route  \
# 0             0.208126                  0.208126            0.146654
# 1             0.273423                  0.273423            0.000574
#
#    Mean_encoded_Source  Mean_encoded_Destination  Mean_encoded_Route  \
# 0          8024.689940               8024.689940         5551.593220
# 1          9143.083566               9143.083566         7369.166667
#
#    Label_encoded_Airline  Label_encoded_Source  Label_encoded_Destination  \
# 0                      3                     0                          2
# 1                      1                     3                          0
#
#    Label_encoded_Route
# 0                   18
# 1                   84

# %%
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
print(metrics.r2_score(y_train,reg.predict(X_train)), metrics.r2_score(y_test,reg.predict(X_test)))
# Out:
# 0.6335614004347756 0.617133270925699

# %%
train(X,y,regression)
# Out:
# 0.6335614004347756 0.617133270925699
# LinearRegression()

# %%
train(X,y,knearestneighbour)
# Out:
# 0.6905083756903938 0.6132897433022917
# KNeighborsRegressor(n_neighbors=10)

# %%
train(X,y,decisiontree)
# Out:
# 0.7180758673831248 0.623023124117474
# DecisionTreeRegressor(max_depth=10)

# %%
train(X,y,randomForest)
# Out:
# 0.7407683121507826 0.625604611143222
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=10,
#                       n_estimators=500)

# %%
train(X,y,xgboost)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 train(X,y,xgboost)
#
# Cell In[170], line 71, in train(X, y, modelType)
#      68 def train(X,y,modelType):
#      69     # Split your dataset into train and test
#      70     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ---> 71     model = modelType(X_train, X_test, y_train, y_test)
#      72     return model
#
# Cell In[170], line 49, in xgboost(X_train, X_test, y_train, y_test)
#      47 def xgboost(X_train, X_test, y_train, y_test):
#      48     xgboost_regressor = XGBRegressor()
# ---> 49     xgboost_regressor.fit(X_train, y_train)
#      50     print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
#      51     return xgboost_regressor
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:761, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
# --> 761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
#     775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:286, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, label_transform)
#     265 def _wrap_evaluation_matrices(
#     266     missing: float,
#     267     X: Any,
#    (...)
#     281     label_transform: Callable = lambda x: x,
#     282 ) -> Tuple[Any, Optional[List[Tuple[Any, str]]]]:
#     283     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the way.
#     284
#     285     """
# --> 286     train_dmatrix = create_dmatrix(
#     287         data=X,
#     288         label=label_transform(y),
#     289         group=group,
#     290         qid=qid,
#     291         weight=sample_weight,
#     292         base_margin=base_margin,
#     293         feature_weights=feature_weights,
#     294         missing=missing,
#     295         enable_categorical=enable_categorical,
#     296     )
#     298     n_validation = 0 if eval_set is None else len(eval_set)
#     300     def validate_or_none(meta: Optional[List], name: str) -> List:
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:775, in XGBModel.fit.<locals>.<lambda>(**kwargs)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
#     761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
# --> 775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:616, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     613     assert self.handle is not None
#     614     return
# --> 616 handle, feature_names, feature_types = dispatch_data_backend(
#     617     data,
#     618     missing=self.missing,
#     619     threads=self.nthread,
#     620     feature_names=feature_names,
#     621     feature_types=feature_types,
#     622     enable_categorical=enable_categorical,
#     623 )
#     624 assert handle is not None
#     625 self.handle = handle
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:772, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     770     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     771 if _is_pandas_df(data):
# --> 772     return _from_pandas_df(data, enable_categorical, missing, threads,
#     773                            feature_names, feature_types)
#     774 if _is_pandas_series(data):
#     775     return _from_pandas_series(
#     776         data, missing, threads, enable_categorical, feature_names, feature_types
#     777     )
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:312, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     304 def _from_pandas_df(
#     305     data: DataFrame,
#     306     enable_categorical: bool,
#    (...)
#     310     feature_types: Optional[List[str]],
#     311 ):
# --> 312     data, feature_names, feature_types = _transform_pandas_df(
#     313         data, enable_categorical, feature_names, feature_types)
#     314     return _from_numpy_array(data, missing, nthread, feature_names,
#     315                              feature_types)
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:262, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     260 if isinstance(data.columns, pd.MultiIndex):
#     261     feature_names = [" ".join([str(x) for x in i]) for i in data.columns]
# --> 262 elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#     263     feature_names = list(map(str, data.columns))
#     264 else:
#
# AttributeError: module 'pandas' has no attribute 'Int64Index'

# %%
train(X,y,catboost)

# %%
train(X,y,gboost)

# %%
## Convert all data into numerical form to obtain your baseline model.

# %%
from sklearn.linear_model import LinearRegression

def sklearn_vif(exogs, data):
    '''
    This function calculates variance inflation function in sklearn way. 
     It is a comparatively faster process.
    '''
    # initialize dictionaries
    vif_dict, tolerance_dict = {}, {}

    # form input data for each exogenous variable
    for exog in exogs:
        not_exog = [i for i in exogs if i != exog]
        X, y = data[not_exog], data[exog]

        # extract r-squared from the fit
        r_squared = LinearRegression().fit(X, y).score(X, y)

        # calculate VIF
        vif = 1/(1 - r_squared)
        vif_dict[exog] = vif

        # calculate tolerance
        tolerance = 1 - r_squared
        tolerance_dict[exog] = tolerance

    # return VIF DataFrame
    df_vif = pd.DataFrame({'VIF': vif_dict, 'Tolerance': tolerance_dict})

    return df_vif

df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)

# %%
# VIF >= 10 shows high collinearity
df_vif

# %%
X.columns

# %%
vif_cols = ['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
       'Mean_encoded_Airline', 
#             'Freq_encoded_Source',
       'Freq_encoded_Destination', 'Freq_encoded_Route', 
#             'Mean_encoded_Source',
#        'Mean_encoded_Destination',
            'Mean_encoded_Route',
       'Label_encoded_Airline', 'Label_encoded_Source',
       'Label_encoded_Destination', 'Label_encoded_Route']
X[vif_cols]
df_vif= sklearn_vif(exogs=vif_cols, data=X[vif_cols]).sort_values(by='VIF',ascending=False)
df_vif

# %%
train(X[vif_cols],y,regression)
train(X[vif_cols],y,knearestneighbour)
train(X[vif_cols],y,decisiontree)
train(X[vif_cols],y,randomForest)
train(X[vif_cols],y,xgboost)
train(X[vif_cols],y,gboost)
train(X[vif_cols],y,catboost)

# %% [markdown]
# ## Scaling and Outlier treatment

# %%
X = X[vif_cols]

# %%
from sklearn.preprocessing import RobustScaler

X_transform = RobustScaler().fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()

# %%
from sklearn.preprocessing import PowerTransformer

X_transform = PowerTransformer().fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()

# %%
from sklearn.preprocessing import FunctionTransformer

X_transform = FunctionTransformer(np.log1p).fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)


train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()

# %%
from sklearn.preprocessing import FunctionTransformer

def cube(X): return X**(0.333)

X_transform = FunctionTransformer(cube).fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=X.columns)


train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False,interaction_only=False)

X_transform = poly.fit_transform(X)
X_transformed = pd.DataFrame(X_transform,columns=poly.get_feature_names(X.columns))

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[179], line 5
#       2 poly = PolynomialFeatures(degree=2, include_bias=False,interaction_only=False)
#       4 X_transform = poly.fit_transform(X)
# ----> 5 X_transformed = pd.DataFrame(X_transform,columns=poly.get_feature_names(X.columns))
#       7 train(X_transformed,y,regression)
#       8 train(X_transformed,y,knearestneighbour)
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'get_feature_names'

# %%
df_transformed =X_transformed.copy(deep=True)
df_transformed['Price'] = y
df_transformed.corr()
# Out:
#                            Total_Stops  Duration_min  Freq_encoded_Airline  \
# Total_Stops                   1.000000      0.833029              0.238676
# Duration_min                  0.833029      1.000000              0.286087
# Freq_encoded_Airline          0.238676      0.286087              1.000000
# Mean_encoded_Airline          0.495547      0.527327              0.562255
# Freq_encoded_Destination      0.622027      0.526736              0.062961
# Freq_encoded_Route           -0.231959     -0.176242              0.028129
# Mean_encoded_Route            0.873023      0.799728              0.327784
# Label_encoded_Airline        -0.043588     -0.067507              0.076743
# Label_encoded_Source          0.363586      0.256266              0.048764
# Label_encoded_Destination    -0.273453     -0.293941             -0.072424
# Label_encoded_Route           0.419845      0.297263             -0.035710
# Price                         0.628434      0.576736              0.333236
#
#                            Mean_encoded_Airline  Freq_encoded_Destination  \
# Total_Stops                            0.495547                  0.622027
# Duration_min                           0.527327                  0.526736
# Freq_encoded_Airline                   0.562255                  0.062961
# Mean_encoded_Airline                   1.000000                  0.290648
# Freq_encoded_Destination               0.290648                  1.000000
# Freq_encoded_Route                     0.107872                  0.142339
# Mean_encoded_Route                     0.607723                  0.541284
# Label_encoded_Airline                  0.058813                 -0.036447
# Label_encoded_Source                   0.086163                  0.205880
# Label_encoded_Destination             -0.069251                 -0.286367
# Label_encoded_Route                    0.060429                  0.419297
# Price                                  0.621681                  0.358239
#
#                            Freq_encoded_Route  Mean_encoded_Route  \
# Total_Stops                         -0.231959            0.873023
# Duration_min                        -0.176242            0.799728
# Freq_encoded_Airline                 0.028129            0.327784
# Mean_encoded_Airline                 0.107872            0.607723
# Freq_encoded_Destination             0.142339            0.541284
# Freq_encoded_Route                   1.000000           -0.058193
# Mean_encoded_Route                  -0.058193            1.000000
# Label_encoded_Airline                0.261863            0.034617
# Label_encoded_Source                -0.134537            0.128345
# Label_encoded_Destination            0.135721           -0.182491
# Label_encoded_Route                 -0.040019            0.175441
# Price                               -0.067489            0.740971
#
#                            Label_encoded_Airline  Label_encoded_Source  \
# Total_Stops                            -0.043588              0.363586
# Duration_min                           -0.067507              0.256266
# Freq_encoded_Airline                    0.076743              0.048764
# Mean_encoded_Airline                    0.058813              0.086163
# Freq_encoded_Destination               -0.036447              0.205880
# Freq_encoded_Route                      0.261863             -0.134537
# Mean_encoded_Route                      0.034617              0.128345
# Label_encoded_Airline                   1.000000              0.016601
# Label_encoded_Source                    0.016601              1.000000
# Label_encoded_Destination               0.065672             -0.497522
# Label_encoded_Route                     0.039632              0.790471
# Price                                   0.053830              0.086463
#
#                            Label_encoded_Destination  Label_encoded_Route  \
# Total_Stops                                -0.273453             0.419845
# Duration_min                               -0.293941             0.297263
# Freq_encoded_Airline                       -0.072424            -0.035710
# Mean_encoded_Airline                       -0.069251             0.060429
# Freq_encoded_Destination                   -0.286367             0.419297
# Freq_encoded_Route                          0.135721            -0.040019
# Mean_encoded_Route                         -0.182491             0.175441
# Label_encoded_Airline                       0.065672             0.039632
# Label_encoded_Source                       -0.497522             0.790471
# Label_encoded_Destination                   1.000000            -0.200016
# Label_encoded_Route                        -0.200016             1.000000
# Price                                      -0.118825             0.097118
#
#                               Price
# Total_Stops                0.628434
# Duration_min               0.576736
# Freq_encoded_Airline       0.333236
# Mean_encoded_Airline       0.621681
# Freq_encoded_Destination   0.358239
# Freq_encoded_Route        -0.067489
# Mean_encoded_Route         0.740971
# Label_encoded_Airline      0.053830
# Label_encoded_Source       0.086463
# Label_encoded_Destination -0.118825
# Label_encoded_Route        0.097118
# Price                      1.000000

# %% [markdown]
# ## Adding Basic Time based Features

# %% [markdown]
# ## I

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

            # 3-8 early_morning
            # 8-12 morning
            # 12-16 afternoon
            # 16-20 evening
            # 20-00 night
            # 00-3 late_night

# %%
df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

# %%
X = df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = df['Price']

# %%
train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)
train(X_transformed,y,randomForest)
train(X_transformed,y,xgboost)
train(X_transformed,y,gboost)
train(X_transformed,y,catboost)
# Out:
# 0.6049492633958418 0.603787589200544
# 0.6905885313638873 0.6209360911955846
# 0.7180758673831248 0.622954737959744
# 0.7406364771701225 0.6266726587575497
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[184], line 5
#       3 train(X_transformed,y,decisiontree)
#       4 train(X_transformed,y,randomForest)
# ----> 5 train(X_transformed,y,xgboost)
#       6 train(X_transformed,y,gboost)
#       7 train(X_transformed,y,catboost)
#
# Cell In[170], line 71, in train(X, y, modelType)
#      68 def train(X,y,modelType):
#      69     # Split your dataset into train and test
#      70     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ---> 71     model = modelType(X_train, X_test, y_train, y_test)
#      72     return model
#
# Cell In[170], line 49, in xgboost(X_train, X_test, y_train, y_test)
#      47 def xgboost(X_train, X_test, y_train, y_test):
#      48     xgboost_regressor = XGBRegressor()
# ---> 49     xgboost_regressor.fit(X_train, y_train)
#      50     print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
#      51     return xgboost_regressor
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:761, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
# --> 761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
#     775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:286, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, label_transform)
#     265 def _wrap_evaluation_matrices(
#     266     missing: float,
#     267     X: Any,
#    (...)
#     281     label_transform: Callable = lambda x: x,
#     282 ) -> Tuple[Any, Optional[List[Tuple[Any, str]]]]:
#     283     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the way.
#     284
#     285     """
# --> 286     train_dmatrix = create_dmatrix(
#     287         data=X,
#     288         label=label_transform(y),
#     289         group=group,
#     290         qid=qid,
#     291         weight=sample_weight,
#     292         base_margin=base_margin,
#     293         feature_weights=feature_weights,
#     294         missing=missing,
#     295         enable_categorical=enable_categorical,
#     296     )
#     298     n_validation = 0 if eval_set is None else len(eval_set)
#     300     def validate_or_none(meta: Optional[List], name: str) -> List:
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:775, in XGBModel.fit.<locals>.<lambda>(**kwargs)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
#     761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
# --> 775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:616, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     613     assert self.handle is not None
#     614     return
# --> 616 handle, feature_names, feature_types = dispatch_data_backend(
#     617     data,
#     618     missing=self.missing,
#     619     threads=self.nthread,
#     620     feature_names=feature_names,
#     621     feature_types=feature_types,
#     622     enable_categorical=enable_categorical,
#     623 )
#     624 assert handle is not None
#     625 self.handle = handle
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:772, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     770     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     771 if _is_pandas_df(data):
# --> 772     return _from_pandas_df(data, enable_categorical, missing, threads,
#     773                            feature_names, feature_types)
#     774 if _is_pandas_series(data):
#     775     return _from_pandas_series(
#     776         data, missing, threads, enable_categorical, feature_names, feature_types
#     777     )
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:312, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     304 def _from_pandas_df(
#     305     data: DataFrame,
#     306     enable_categorical: bool,
#    (...)
#     310     feature_types: Optional[List[str]],
#     311 ):
# --> 312     data, feature_names, feature_types = _transform_pandas_df(
#     313         data, enable_categorical, feature_names, feature_types)
#     314     return _from_numpy_array(data, missing, nthread, feature_names,
#     315                              feature_types)
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:262, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     260 if isinstance(data.columns, pd.MultiIndex):
#     261     feature_names = [" ".join([str(x) for x in i]) for i in data.columns]
# --> 262 elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#     263     feature_names = list(map(str, data.columns))
#     264 else:
#
# AttributeError: module 'pandas' has no attribute 'Int64Index'

# %% [markdown]
# ## II

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

        # 3-8 early_morning
        # 8-12 morning
        # 12-16 afternoon
        # 16-20 evening
        # 20-00 night
        # 00-3 late_night
        
df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])

df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])

new_df = pd.concat([df,df_oneHotEncoded],axis=1)

new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

print(X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)

model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T

model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

# %% [markdown]
# ## III

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)

# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night

df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['dep_day_of_week'] = df['DepartureDateTime'].dt.day_of_week 
df['arr_day_of_week'] = df['ArrivalDateTime'].dt.day_of_week 

df['dep_weekday'] = np.where(df["dep_day_of_week"].isin([5,6]),0,1)
df['arr_weekday'] = np.where(df["arr_day_of_week"].isin([5,6]),0,1)


df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
new_df = pd.concat([df,df_oneHotEncoded],axis=1)
new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

print(X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

print(X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)

model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T

model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

# %% [markdown]
# ## IV

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)
# 3-8 early_morning
# 8-12 morning
# 12-16 afternoon
# 16-20 evening
# 20-00 night
# 00-3 late_night



df['dep_hr'] = df['DepartureDateTime'].dt.hour
df['arr_hr'] = df['ArrivalDateTime'].dt.hour

df['dep_month'] = df['DepartureDateTime'].dt.month
df['dep_day_of_month'] = df['DepartureDateTime'].dt.day

df['arr_month'] = df['ArrivalDateTime'].dt.month
df['arr_day_of_month'] = df['ArrivalDateTime'].dt.day

df['dep_day_of_week'] = df['DepartureDateTime'].dt.day_of_week 
df['arr_day_of_week'] = df['ArrivalDateTime'].dt.day_of_week 

df['dep_weekday'] = np.where(df["dep_day_of_week"].isin([5,6]),0,1)
df['arr_weekday'] = np.where(df["arr_day_of_week"].isin([5,6]),0,1)


df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])
df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
new_df = pd.concat([df,df_oneHotEncoded],axis=1)
new_df.drop(columns=one_hot_cols,inplace=True)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

print(X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)


model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T

model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)

model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

# %%
X = new_df.drop(columns=['Price','DepartureDateTime','Duration_timedelta','ArrivalDateTime'])
y = new_df['Price']

print(X.columns)

train(X_transformed,y,regression)
train(X_transformed,y,knearestneighbour)
train(X_transformed,y,decisiontree)

# %%
model = train(X,y,randomForest)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

# %%
model = train(X,y,gboost)
pd.DataFrame({'feature_names_in_':model.feature_names_in_,'feature_importances_':model.feature_importances_}).sort_values(by='feature_importances_',ascending=False)

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T

# %%
model = train(X,y,catboost)
pd.DataFrame({'feature_names_in_':X.columns,'feature_importances_':model.get_feature_importance()}).sort_values(by='feature_importances_',ascending=False)

# %%
## After doing Time-based feature Engineering we found best model to be xgboost.

# %%
model = train(X,y,xgboost)
importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')
​
pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T

# %%
df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)

# %%
df_vif
# Out:
#                                             VIF  Tolerance
# arrival_timeOfDay_encoded                   inf   0.000000
# departure_timeOfDay_encoded                 inf   0.000000
# arrival_timeOfDay_morning                   inf   0.000000
# arrival_timeOfDay_late_night                inf   0.000000
# arrival_timeOfDay_evening                   inf   0.000000
# arrival_timeOfDay_early_morning             inf   0.000000
# arrival_timeOfDay_after_noon                inf   0.000000
# departure_timeOfDay_night                   inf   0.000000
# departure_timeOfDay_morning                 inf   0.000000
# departure_timeOfDay_late_night              inf   0.000000
# departure_timeOfDay_evening                 inf   0.000000
# departure_timeOfDay_early_morning           inf   0.000000
# departure_timeOfDay_after_noon              inf   0.000000
# arrival_timeOfDay_night                     inf   0.000000
# Mean_encoded_Destination                    inf   0.000000
# Freq_encoded_Source                         inf   0.000000
# Freq_encoded_Destination                    inf   0.000000
# Mean_encoded_Source                         inf   0.000000
# Label_encoded_Destination          5.758928e+04   0.000017
# Label_encoded_Source               1.295934e+04   0.000077
# Label_encoded_Route                5.446210e+01   0.018361
# dep_hr                             1.769459e+01   0.056514
# arr_hr                             1.095586e+01   0.091275
# dep_weekday                        9.841619e+00   0.101609
# arr_weekday                        9.093601e+00   0.109967
# Total_Stops                        8.323085e+00   0.120148
# dep_day_of_week                    7.031535e+00   0.142216
# arr_day_of_week                    6.622844e+00   0.150993
# Mean_encoded_Route                 6.187528e+00   0.161615
# Duration_min                       2.440320e+00   0.409782
# Mean_encoded_Airline               2.142951e+00   0.466646
# Freq_encoded_Route                 2.069583e+00   0.483189
# Freq_encoded_Airline               1.903277e+00   0.525410
# Label_encoded_Airline              1.233163e+00   0.810923

# %%
vif_cols = ['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
       'Mean_encoded_Airline', 
#             'Freq_encoded_Source',
       'Freq_encoded_Destination', 'Freq_encoded_Route', 
#             'Mean_encoded_Source',
#        'Mean_encoded_Destination',
            'Mean_encoded_Route',
       'Label_encoded_Airline', 'Label_encoded_Source',
       'Label_encoded_Destination', 'Label_encoded_Route', 'dep_hr', 'arr_hr',
#        'departure_timeOfDay_encoded',
            'arrival_timeOfDay_encoded',
       'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday',
       'dep_month', 'dep_day_of_month', 
#             'arr_month', 
#             'arr_day_of_month',
       'departure_timeOfDay_after_noon', 
#             'departure_timeOfDay_early_morning',
#        'departure_timeOfDay_evening',
            'departure_timeOfDay_late_night',
       'departure_timeOfDay_morning', 'departure_timeOfDay_night',
       'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning',
       'arrival_timeOfDay_evening', 
#             'arrival_timeOfDay_late_night',
#        'arrival_timeOfDay_morning', 
#             'arrival_timeOfDay_night'
           ]

X =X[vif_cols]

df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)
df_vif
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 28
#       1 vif_cols = ['Total_Stops', 'Duration_min', 'Freq_encoded_Airline',
#       2        'Mean_encoded_Airline',
#       3 #             'Freq_encoded_Source',
#    (...)
#      25 #             'arrival_timeOfDay_night'
#      26            ]
# ---> 28 X =X[vif_cols]
#      30 df_vif= sklearn_vif(exogs=X.columns, data=X).sort_values(by='VIF',ascending=False)
#      31 df_vif
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['arrival_timeOfDay_encoded', 'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday', 'dep_month', 'dep_day_of_month', 'departure_timeOfDay_after_noon', 'departure_timeOfDay_late_night', 'departure_timeOfDay_morning', 'departure_timeOfDay_night', 'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning', 'arrival_timeOfDay_evening'] not in index"

# %%
model = train(X[vif_cols],y,xgboost)

importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 model = train(X[vif_cols],y,xgboost)
#       3 importance_gain = model.get_booster().get_score(importance_type='gain')
#       4 importance_cover = model.get_booster().get_score(importance_type='cover')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['arrival_timeOfDay_encoded', 'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday', 'dep_month', 'dep_day_of_month', 'departure_timeOfDay_after_noon', 'departure_timeOfDay_late_night', 'departure_timeOfDay_morning', 'departure_timeOfDay_night', 'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning', 'arrival_timeOfDay_evening'] not in index"

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_validate

# %%
from xgboost import XGBRegressor
Xgboost_reg = XGBRegressor()

# %%
estimator = Xgboost_reg
X = X[vif_cols]
y = y
number_of_cross_validation = 5

def basic_cross_validation(estimator,X,y,number_of_cross_validation=5):
    scores = cross_validate(estimator, X, y, cv=number_of_cross_validation,
                             scoring=('r2', 'neg_mean_squared_error'),
                             return_train_score=True)

    print(scores['train_r2'])
    print(scores['train_r2'].mean())

    print(scores['test_r2'])
    print(scores['test_r2'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 2
#       1 estimator = Xgboost_reg
# ----> 2 X = X[vif_cols]
#       3 y = y
#       4 number_of_cross_validation = 5
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['arrival_timeOfDay_encoded', 'dep_day_of_week', 'arr_day_of_week', 'dep_weekday', 'arr_weekday', 'dep_month', 'dep_day_of_month', 'departure_timeOfDay_after_noon', 'departure_timeOfDay_late_night', 'departure_timeOfDay_morning', 'departure_timeOfDay_night', 'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning', 'arrival_timeOfDay_evening'] not in index"

# %%
from catboost import CatBoostRegressor

# %%
basic_cross_validation(CatBoostRegressor(verbose=False),X[vif_cols],y,number_of_cross_validation=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 basic_cross_validation(CatBoostRegressor(verbose=False),X[vif_cols],y,number_of_cross_validation=5)
#
# NameError: name 'basic_cross_validation' is not defined

# %% [markdown]
# #### Actions taken in feature Engineering

# %%
def time_of_day(hr):
    '''
    This function gives the time of day based on logic:
        # 3-8 early_morning or 1
        # 8-12 morning or 2
        # 12-16 afternoon or 3
        # 16-20 evening or 4
        # 20-00 night or 5
        # 00-3 late_night or 6
        # invalid or 0
    input:
        hr
    return: tuple
        (timeOfDay,timeOfDay_encoded
    '''
    if hr in range(0,3) :
        str_val = 'late_night'
        val = 6
    elif hr in range(20,23):
        str_val = 'night'
        val = 5
    elif hr in range(16,20):
        str_val = 'evening'
        val = 4
    elif hr in range(12,26):
        str_val = 'after_noon'
        val = 3
    elif hr in range(8,12):
        str_val = 'morning'
        val = 2
    elif hr in range(3,8):
        str_val = 'early_morning'
        val = 1
    else:
        str_val = 'invalid'
        val = 0
    return (str_val, val)


def time_based_feature_Engineering(df):

    df['dep_hr'] = df['DepartureDateTime'].dt.hour
    df['arr_hr'] = df['ArrivalDateTime'].dt.hour

    df['dep_month'] = df['DepartureDateTime'].dt.month
    df['dep_day_of_month'] = df['DepartureDateTime'].dt.day

    df['arr_month'] = df['ArrivalDateTime'].dt.month
    df['arr_day_of_month'] = df['ArrivalDateTime'].dt.day

    df['dep_day_of_week'] = df['DepartureDateTime'].dt.day_of_week 
    df['arr_day_of_week'] = df['ArrivalDateTime'].dt.day_of_week 

    df['dep_weekday'] = np.where(df["dep_day_of_week"].isin([5,6]),0,1)
    df['arr_weekday'] = np.where(df["arr_day_of_week"].isin([5,6]),0,1)


    df['departure_timeOfDay'] = df['dep_hr'].apply(lambda x: time_of_day(x)[0])
    df['departure_timeOfDay_encoded'] = df['dep_hr'].apply(lambda x: time_of_day(x)[1])
    df['arrival_timeOfDay'] = df['arr_hr'].apply(lambda x: time_of_day(x)[0])
    df['arrival_timeOfDay_encoded'] = df['arr_hr'].apply(lambda x: time_of_day(x)[1])

    one_hot_cols = ['departure_timeOfDay','arrival_timeOfDay']
    df_oneHotEncoded = pd.get_dummies(df[one_hot_cols])
    new_df = pd.concat([df,df_oneHotEncoded],axis=1)
    
    drop_cols = [
                'DepartureDateTime',
                'Duration_timedelta',
                'ArrivalDateTime',
                'Freq_encoded_Source',
                'Mean_encoded_Source',
                'Mean_encoded_Destination',
                'departure_timeOfDay_encoded',
                'arr_month', 
                'arr_day_of_month',
                'departure_timeOfDay_early_morning',
                'departure_timeOfDay_evening',
                'arrival_timeOfDay_late_night',
                'arrival_timeOfDay_morning', 
                'arrival_timeOfDay_night']
    
    new_df.drop(columns=one_hot_cols,inplace=True)
    new_df.drop(columns=drop_cols,inplace=True)
    return new_df

# %%
final_df = time_based_feature_Engineering(df)

# %%
final_df.to_csv("FinalData.csv",index=False)

# %%
final_df.columns
# Out:
# Index(['Total_Stops', 'Price', 'Duration_min', 'Freq_encoded_Airline',
#        'Mean_encoded_Airline', 'Freq_encoded_Destination',
#        'Freq_encoded_Route', 'Mean_encoded_Route', 'Label_encoded_Airline',
#        'Label_encoded_Source', 'Label_encoded_Destination',
#        'Label_encoded_Route', 'dep_hr', 'arr_hr', 'dep_month',
#        'dep_day_of_month', 'dep_day_of_week', 'arr_day_of_week', 'dep_weekday',
#        'arr_weekday', 'arrival_timeOfDay_encoded',
#        'departure_timeOfDay_after_noon', 'departure_timeOfDay_late_night',
#        'departure_timeOfDay_morning', 'departure_timeOfDay_night',
#        'arrival_timeOfDay_after_noon', 'arrival_timeOfDay_early_morning',
#        'arrival_timeOfDay_evening'],
#       dtype='object')

# %%
X = final_df.drop(columns='Price')
y = final_df['Price']
model = train(X,y,xgboost)

importance_gain = model.get_booster().get_score(importance_type='gain')
importance_cover = model.get_booster().get_score(importance_type='cover')
importance_weight = model.get_booster().get_score(importance_type='weight')
importance_total_gain = model.get_booster().get_score(importance_type='total_gain')
importance_total_cover = model.get_booster().get_score(importance_type='total_cover')

pd.DataFrame([importance_weight,importance_gain,importance_total_gain,importance_cover,importance_total_cover],index=['weight','gain','total_gain','cover','total_cover']).T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[197], line 3
#       1 X = final_df.drop(columns='Price')
#       2 y = final_df['Price']
# ----> 3 model = train(X,y,xgboost)
#       5 importance_gain = model.get_booster().get_score(importance_type='gain')
#       6 importance_cover = model.get_booster().get_score(importance_type='cover')
#
# Cell In[170], line 71, in train(X, y, modelType)
#      68 def train(X,y,modelType):
#      69     # Split your dataset into train and test
#      70     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ---> 71     model = modelType(X_train, X_test, y_train, y_test)
#      72     return model
#
# Cell In[170], line 49, in xgboost(X_train, X_test, y_train, y_test)
#      47 def xgboost(X_train, X_test, y_train, y_test):
#      48     xgboost_regressor = XGBRegressor()
# ---> 49     xgboost_regressor.fit(X_train, y_train)
#      50     print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
#      51     return xgboost_regressor
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:761, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
# --> 761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
#     775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:286, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, label_transform)
#     265 def _wrap_evaluation_matrices(
#     266     missing: float,
#     267     X: Any,
#    (...)
#     281     label_transform: Callable = lambda x: x,
#     282 ) -> Tuple[Any, Optional[List[Tuple[Any, str]]]]:
#     283     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the way.
#     284
#     285     """
# --> 286     train_dmatrix = create_dmatrix(
#     287         data=X,
#     288         label=label_transform(y),
#     289         group=group,
#     290         qid=qid,
#     291         weight=sample_weight,
#     292         base_margin=base_margin,
#     293         feature_weights=feature_weights,
#     294         missing=missing,
#     295         enable_categorical=enable_categorical,
#     296     )
#     298     n_validation = 0 if eval_set is None else len(eval_set)
#     300     def validate_or_none(meta: Optional[List], name: str) -> List:
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:775, in XGBModel.fit.<locals>.<lambda>(**kwargs)
#     687 """Fit gradient boosting model.
#     688
#     689 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     758
#     759 """
#     760 evals_result: TrainingCallback.EvalsLog = {}
#     761 train_dmatrix, evals = _wrap_evaluation_matrices(
#     762     missing=self.missing,
#     763     X=X,
#     764     y=y,
#     765     group=None,
#     766     qid=None,
#     767     sample_weight=sample_weight,
#     768     base_margin=base_margin,
#     769     feature_weights=feature_weights,
#     770     eval_set=eval_set,
#     771     sample_weight_eval_set=sample_weight_eval_set,
#     772     base_margin_eval_set=base_margin_eval_set,
#     773     eval_group=None,
#     774     eval_qid=None,
# --> 775     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     776     enable_categorical=self.enable_categorical,
#     777 )
#     778 params = self.get_xgb_params()
#     780 if callable(self.objective):
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:616, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     613     assert self.handle is not None
#     614     return
# --> 616 handle, feature_names, feature_types = dispatch_data_backend(
#     617     data,
#     618     missing=self.missing,
#     619     threads=self.nthread,
#     620     feature_names=feature_names,
#     621     feature_types=feature_types,
#     622     enable_categorical=enable_categorical,
#     623 )
#     624 assert handle is not None
#     625 self.handle = handle
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:772, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     770     return _from_tuple(data, missing, threads, feature_names, feature_types)
#     771 if _is_pandas_df(data):
# --> 772     return _from_pandas_df(data, enable_categorical, missing, threads,
#     773                            feature_names, feature_types)
#     774 if _is_pandas_series(data):
#     775     return _from_pandas_series(
#     776         data, missing, threads, enable_categorical, feature_names, feature_types
#     777     )
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:312, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     304 def _from_pandas_df(
#     305     data: DataFrame,
#     306     enable_categorical: bool,
#    (...)
#     310     feature_types: Optional[List[str]],
#     311 ):
# --> 312     data, feature_names, feature_types = _transform_pandas_df(
#     313         data, enable_categorical, feature_names, feature_types)
#     314     return _from_numpy_array(data, missing, nthread, feature_names,
#     315                              feature_types)
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:262, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     260 if isinstance(data.columns, pd.MultiIndex):
#     261     feature_names = [" ".join([str(x) for x in i]) for i in data.columns]
# --> 262 elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#     263     feature_names = list(map(str, data.columns))
#     264 else:
#
# AttributeError: module 'pandas' has no attribute 'Int64Index'

# %%
model

# %% [markdown]
# ## Paramter optimization

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "learning_rate" : [0.1,0.2,0.3,0.5,],
    "max_depth" : [4,5,6,7],
    "n_estimators" : [100,200,300,400,500]
}

# %%
reg = RandomizedSearchCV(XGBRegressor(),param_grid,random_state=0)

# %%
model = reg.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 model = reg.fit(X,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1806, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1804 def _run_search(self, evaluate_candidates):
#    1805     """Search n_iter candidates from param_distributions"""
# -> 1806     evaluate_candidates(
#    1807         ParameterSampler(
#    1808             self.param_distributions, self.n_iter, random_state=self.random_state
#    1809         )
#    1810     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 50 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#            ^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 761, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 286, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 775, in <lambda>
#     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#            ^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 616, in __init__
#     handle, feature_names, feature_types = dispatch_data_backend(
#                                            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 772, in dispatch_data_backend
#     return _from_pandas_df(data, enable_categorical, missing, threads,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 312, in _from_pandas_df
#     data, feature_names, feature_types = _transform_pandas_df(
#                                          ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 262, in _transform_pandas_df
#     elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                                    ^^^^^^^^^^^^^
# AttributeError: module 'pandas' has no attribute 'Int64Index'

# %%
model.best_estimator_

# %%
model

# %%
basic_cross_validation(model.best_estimator_,X,y,number_of_cross_validation=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 basic_cross_validation(model.best_estimator_,X,y,number_of_cross_validation=5)
#
# NameError: name 'basic_cross_validation' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
xgboost_regressor = model.best_estimator_
xgboost_regressor.fit(X_train, y_train)
print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[205], line 2
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ----> 2 xgboost_regressor = model.best_estimator_
#       3 xgboost_regressor.fit(X_train, y_train)
#       4 print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
#
# AttributeError: 'CatBoostRegressor' object has no attribute 'best_estimator_'

# %%
param_grid = {
    "learning_rate" : [0.2,0.21,0.29],
    "n_estimators" : [95,100,105]
}

# %%
reg = GridSearchCV(XGBRegressor(),param_grid)

# %%
model = reg.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 model = reg.fit(X,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 45 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#            ^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 761, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 286, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\sklearn.py", line 775, in <lambda>
#     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 506, in inner_f
#     return f(**kwargs)
#            ^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\core.py", line 616, in __init__
#     handle, feature_names, feature_types = dispatch_data_backend(
#                                            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 772, in dispatch_data_backend
#     return _from_pandas_df(data, enable_categorical, missing, threads,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 312, in _from_pandas_df
#     data, feature_names, feature_types = _transform_pandas_df(
#                                          ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\anaconda3\Lib\site-packages\xgboost\data.py", line 262, in _transform_pandas_df
#     elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#                                    ^^^^^^^^^^^^^
# AttributeError: module 'pandas' has no attribute 'Int64Index'

# %%
model.best_estimator_

# %%
model

# %%
basic_cross_validation(model.best_estimator_,X,y,number_of_cross_validation=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 basic_cross_validation(model.best_estimator_,X,y,number_of_cross_validation=5)
#
# NameError: name 'basic_cross_validation' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
xgboost_regressor = model.best_estimator_
xgboost_regressor.fit(X_train, y_train)
print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[210], line 2
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ----> 2 xgboost_regressor = model.best_estimator_
#       3 xgboost_regressor.fit(X_train, y_train)
#       4 print(metrics.r2_score(y_train,xgboost_regressor.predict(X_train)),metrics.r2_score(y_test,xgboost_regressor.predict(X_test)))
#
# AttributeError: 'CatBoostRegressor' object has no attribute 'best_estimator_'

# %%
# XGBRegressor( learning_rate=0.21, max_depth=6,  n_estimators=100)

# %%
import pickle

# %%
with open('../models/xgboost.pickle','wb') as file:
        pickle.dump(xgboost_regressor,file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 with open('../models/xgboost.pickle','wb') as file:
#       2         pickle.dump(xgboost_regressor,file)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/xgboost.pickle'
